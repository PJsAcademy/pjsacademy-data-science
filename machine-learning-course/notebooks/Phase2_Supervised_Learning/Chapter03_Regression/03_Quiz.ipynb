# %% [markdown]
# # Chapter 03 — Quiz: Regression
# ### PJ's Academy · Machine Learning Mastery
#
# Answer from memory, then re-read the tutorial to check.
#
# ---

# %% [markdown]
# **Q1.** Explain in your own words: Regression fits `y = w·x + b`; training minimizes **MSE**.

# %% [markdown]
# **Q2.** Explain in your own words: Evaluate with **RMSE/MAE** (error size) and **R²** (variance explained).

# %% [markdown]
# **Q3.** Explain in your own words: **Polynomial features** let linear models fit curves — but overfit if too high.

# %% [markdown]
# **Q4.** Explain in your own words: **Regularization** (Ridge/Lasso) fights overfitting; Lasso also selects features.

# %% [markdown]
# **Q5.** Explain in your own words: **Scale features** before regularized models.

# %% [markdown]
# **Q6.** Explain in your own words: **Residual plots** reveal what the model is missing. Always start with a simple baseline.

# %% [markdown]
# ---
# *Check your answers against the tutorial's Key Takeaways.*
