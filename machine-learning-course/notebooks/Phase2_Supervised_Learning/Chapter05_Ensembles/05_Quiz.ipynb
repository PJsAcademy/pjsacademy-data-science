# %% [markdown]
# # Chapter 05 — Quiz: Ensembles
# ### PJ's Academy · Machine Learning Mastery
#
# Answer from memory, then re-read the tutorial to check.
#
# ---

# %% [markdown]
# **Q1.** Explain in your own words: Ensembles combine many models so errors cancel — the best tabular approach.

# %% [markdown]
# **Q2.** Explain in your own words: **Bagging (Random Forest)** cuts variance; **Boosting (XGBoost)** cuts bias.

# %% [markdown]
# **Q3.** Explain in your own words: **Random Forest** = robust default, feature importance, no scaling.

# %% [markdown]
# **Q4.** Explain in your own words: **XGBoost/LightGBM** = usually the most accurate; tune `learning_rate` + `n_estimators` + `max_depth`.

# %% [markdown]
# **Q5.** Explain in your own words: Use **early stopping** and row/feature **subsampling** to control overfitting.

# %% [markdown]
# **Q6.** Explain in your own words: **Stacking** squeezes out the last bit of performance.

# %% [markdown]
# ---
# *Check your answers against the tutorial's Key Takeaways.*
