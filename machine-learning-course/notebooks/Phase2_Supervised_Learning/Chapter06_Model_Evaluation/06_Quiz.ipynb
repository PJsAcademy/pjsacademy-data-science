# %% [markdown]
# # Chapter 06 — Quiz: Model Evaluation
# ### PJ's Academy · Machine Learning Mastery
#
# Answer from memory, then re-read the tutorial to check.
#
# ---

# %% [markdown]
# **Q1.** Explain in your own words: Judge only on **unseen data**; use **cross-validation** for stable estimates.

# %% [markdown]
# **Q2.** Explain in your own words: Error = **bias + variance**; diagnose with learning curves and fix accordingly.

# %% [markdown]
# **Q3.** Explain in your own words: Pick the **metric that matches the cost** — accuracy lies on imbalanced data.

# %% [markdown]
# **Q4.** Explain in your own words: Use a **train/validation/test** split (or CV + final test) so tuning doesn't corrupt your estimate.

# %% [markdown]
# **Q5.** Explain in your own words: **Leakage** is the silent killer — fit preprocessing on train only.

# %% [markdown]
# **Q6.** Explain in your own words: Look **beyond one number**: confusion matrix, calibration, error analysis, per-slice metrics.

# %% [markdown]
# ---
# *Check your answers against the tutorial's Key Takeaways.*
