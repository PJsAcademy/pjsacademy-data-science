# %% [markdown]
# # Chapter 04 — Quiz: Classification
# ### PJ's Academy · Machine Learning Mastery
#
# Answer from memory, then re-read the tutorial to check.
#
# ---

# %% [markdown]
# **Q1.** Explain in your own words: Classification predicts a **category**, usually via a **probability** you threshold.

# %% [markdown]
# **Q2.** Explain in your own words: **Logistic Regression** = sigmoid over a linear score; strong interpretable baseline.

# %% [markdown]
# **Q3.** Explain in your own words: **kNN** (scale it!), **Naive Bayes** (text), **Decision Trees** (readable, limit depth).

# %% [markdown]
# **Q4.** Explain in your own words: **Accuracy lies on imbalanced data** — use the **confusion matrix**, precision, recall, F1, ROC-AUC.

# %% [markdown]
# **Q5.** Explain in your own words: Trade **precision vs recall** by the threshold, based on business cost.

# %% [markdown]
# **Q6.** Explain in your own words: Handle **imbalance** with class weights / resampling and the right metrics.

# %% [markdown]
# ---
# *Check your answers against the tutorial's Key Takeaways.*
