# %% [markdown]
# # Chapter 09 — Quiz: Neural Networks
# ### PJ's Academy · Machine Learning Mastery
#
# Answer from memory, then re-read the tutorial to check.
#
# ---

# %% [markdown]
# **Q1.** Explain in your own words: A neuron = weighted sum + **activation**; stacking many in layers learns complex patterns.

# %% [markdown]
# **Q2.** Explain in your own words: **Activations** (ReLU/sigmoid/softmax) add the non-linearity that makes networks powerful.

# %% [markdown]
# **Q3.** Explain in your own words: Networks learn by **forward pass → loss → backprop → update**, repeated over epochs.

# %% [markdown]
# **Q4.** Explain in your own words: **Adam** optimizer + right loss (cross-entropy/MSE); always **scale inputs**.

# %% [markdown]
# **Q5.** Explain in your own words: Fight overfitting with **dropout, early stopping, more data**.

# %% [markdown]
# **Q6.** Explain in your own words: For **tabular data, XGBoost usually wins** — use deep learning for images/text/audio/huge data.

# %% [markdown]
# ---
# *Check your answers against the tutorial's Key Takeaways.*
