# %% [markdown]
# # Chapter 10 — Quiz: ML in Production
# ### PJ's Academy · Machine Learning Mastery
#
# Answer from memory, then re-read the tutorial to check.
#
# ---

# %% [markdown]
# **Q1.** Explain in your own words: Production ML = reliable serving + monitoring + retraining, not just a good test score.

# %% [markdown]
# **Q2.** Explain in your own words: **Save the whole pipeline**; serve it via an **API** (FastAPI + Docker).

# %% [markdown]
# **Q3.** Explain in your own words: **Drift** silently kills models — monitor inputs, predictions, and live metrics.

# %% [markdown]
# **Q4.** Explain in your own words: Have a **retraining strategy** and validate challengers before promoting.

# %% [markdown]
# **Q5.** Explain in your own words: **MLOps** brings versioning, tracking, registries, and CI/CD to ML.

# %% [markdown]
# **Q6.** Explain in your own words: Build **fair, explainable** models with human oversight for high-stakes calls.

# %% [markdown]
# ---
# *Check your answers against the tutorial's Key Takeaways.*
