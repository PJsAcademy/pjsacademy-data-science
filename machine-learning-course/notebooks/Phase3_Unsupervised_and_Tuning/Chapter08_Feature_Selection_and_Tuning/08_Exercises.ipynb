# %% [markdown]
# # Chapter 08 — Exercises: Feature Selection & Tuning
# ### PJ's Academy · Machine Learning Mastery
#
# Try each yourself in the empty code cell before checking the tutorial.
#
# ---

# %% [markdown]
# ## 🏋️ Exercises
# 1. Run GridSearchCV over 2–3 hyperparameters; report best params and CV score.
# 2. Compare grid vs random search speed and result on the same model.
# 3. Wrap a scaler + model in a Pipeline and tune with the `model__` prefix.
# 4. (Bonus) Use Optuna for 30 trials on XGBoost; beat your grid-search score.

# %% [markdown]
# **1. Run GridSearchCV over 2–3 hyperparameters; report best params and CV score.**

# %%
# your solution here

# %% [markdown]
# **2. Compare grid vs random search speed and result on the same model.**

# %%
# your solution here

# %% [markdown]
# **3. Wrap a scaler + model in a Pipeline and tune with the `model__` prefix.**

# %%
# your solution here

# %% [markdown]
# **4. (Bonus) Use Optuna for 30 trials on XGBoost; beat your grid-search score.**

# %%
# your solution here
