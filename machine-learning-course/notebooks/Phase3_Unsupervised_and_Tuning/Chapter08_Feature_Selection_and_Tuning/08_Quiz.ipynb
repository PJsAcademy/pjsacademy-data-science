# %% [markdown]
# # Chapter 08 — Quiz: Feature Selection & Tuning
# ### PJ's Academy · Machine Learning Mastery
#
# Answer from memory, then re-read the tutorial to check.
#
# ---

# %% [markdown]
# **Q1.** Explain in your own words: **Feature selection** (filter, model-based, RFE) cuts noise and overfitting.

# %% [markdown]
# **Q2.** Explain in your own words: **Tuning** = searching hyperparameters: **grid** (small spaces), **random** (bigger), **Bayesian/Optuna** (best).

# %% [markdown]
# **Q3.** Explain in your own words: Tune only the **high-impact hyperparameters** per model.

# %% [markdown]
# **Q4.** Explain in your own words: Use **Pipelines** so preprocessing is tuned/CV'd without leakage.

# %% [markdown]
# **Q5.** Explain in your own words: **Fix features before you tune** — engineering usually beats optimization.

# %% [markdown]
# **Q6.** Explain in your own words: Confirm the final model on the **untouched test set**.

# %% [markdown]
# ---
# *Check your answers against the tutorial's Key Takeaways.*
