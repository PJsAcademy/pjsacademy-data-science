# %% [markdown]
# # Chapter 07 — Quiz: Unsupervised Learning
# ### PJ's Academy · Machine Learning Mastery
#
# Answer from memory, then re-read the tutorial to check.
#
# ---

# %% [markdown]
# **Q1.** Explain in your own words: Unsupervised learning finds **structure without labels** — clustering and dimensionality reduction.

# %% [markdown]
# **Q2.** Explain in your own words: **K-Means** groups by nearest centre; **scale first**, pick k with the elbow/silhouette.

# %% [markdown]
# **Q3.** Explain in your own words: **DBSCAN/hierarchical** handle non-round clusters and unknown k.

# %% [markdown]
# **Q4.** Explain in your own words: **PCA** compresses correlated features while keeping variance — for speed, denoising, and visualization.

# %% [markdown]
# **Q5.** Explain in your own words: **t-SNE/UMAP** are for plots only, not model inputs.

# %% [markdown]
# **Q6.** Explain in your own words: Evaluate with silhouette/explained variance — but **business usefulness** is the real test.

# %% [markdown]
# ---
# *Check your answers against the tutorial's Key Takeaways.*
