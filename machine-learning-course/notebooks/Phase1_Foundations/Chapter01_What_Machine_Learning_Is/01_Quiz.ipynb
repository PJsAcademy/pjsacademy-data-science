# %% [markdown]
# # Chapter 01 — Quiz: What Machine Learning Is
# ### PJ's Academy · Machine Learning Mastery
#
# Answer from memory, then re-read the tutorial to check.
#
# ---

# %% [markdown]
# **Q1.** Explain in your own words: ML learns **rules from examples** instead of you writing them.

# %% [markdown]
# **Q2.** Explain in your own words: **Supervised** (labelled) = regression (numbers) + classification (categories); **unsupervised** finds structure.

# %% [markdown]
# **Q3.** Explain in your own words: Always **train/test split** — test performance is the only honest measure.

# %% [markdown]
# **Q4.** Explain in your own words: **Data leakage** silently inflates scores — protect the test set.

# %% [markdown]
# **Q5.** Explain in your own words: The game is balancing **underfitting vs overfitting**.

# %% [markdown]
# **Q6.** Explain in your own words: Follow the **8-step workflow** every time.

# %% [markdown]
# ---
# *Check your answers against the tutorial's Key Takeaways.*
