# %% [markdown]
# # Chapter 02 — Quiz: Data & Feature Engineering
# ### PJ's Academy · Machine Learning Mastery
#
# Answer from memory, then re-read the tutorial to check.
#
# ---

# %% [markdown]
# **Q1.** Explain in your own words: **EDA first** — understand data before modelling.

# %% [markdown]
# **Q2.** Explain in your own words: **Impute** missing values (median/mode); fit on train only.

# %% [markdown]
# **Q3.** Explain in your own words: **One-hot** unordered categories, **ordinal-encode** ordered ones.

# %% [markdown]
# **Q4.** Explain in your own words: **Scale** features for distance/gradient models; trees don't need it.

# %% [markdown]
# **Q5.** Explain in your own words: **Feature engineering** (ratios, dates, bins) is the highest-leverage move.

# %% [markdown]
# **Q6.** Explain in your own words: Use **pipelines** to apply steps consistently and avoid leakage.

# %% [markdown]
# ---
# *Check your answers against the tutorial's Key Takeaways.*
