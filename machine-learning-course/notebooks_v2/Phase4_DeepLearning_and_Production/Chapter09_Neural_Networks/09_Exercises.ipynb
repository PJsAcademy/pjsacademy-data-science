# %% [markdown]
# # Module 9 — Exercises: Neural Networks: The Intuition
# ### Machine Learning Mastery — PJ's Academy
#
# Try each before checking the Tutorial.
#
# ---

# %% [markdown]
# ## Exercise 1
# Build a Keras network for a binary classification dataset; plot train vs val loss.

# %%
# your answer here

# %% [markdown]
# ## Exercise 2
# Add/remove Dropout and compare overfitting.

# %%
# your answer here

# %% [markdown]
# ## Exercise 3
# Compare your neural net vs XGBoost on the same tabular data — which wins, and why?

# %%
# your answer here

# %% [markdown]
# ## Exercise 4
# Change the learning rate (0.1, 0.001) and observe training stability.

# %%
# your answer here
