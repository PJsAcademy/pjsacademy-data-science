# %% [markdown]
# # Module 9 — Interview Q&A: Neural Networks: The Intuition
# ### Machine Learning Mastery — PJ's Academy

# %% [markdown]
# > **Optional Reading**
# > Interview questions for self-study — not required before the next module.
# > Return here when preparing for interviews.

# %% [markdown]
# ## 🟢 Junior
# ### Q1: What is — A neuron = weighted sum + **activation**; stacking many in layers learns complex patterns.
#
# **Answer:**
# A neuron = weighted sum + **activation**; stacking many in layers learns complex patterns. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q2: How does — **Activations** (ReLU/sigmoid/softmax) add the non-linearity that makes networks powerful.
#
# **Answer:**
# **Activations** (ReLU/sigmoid/softmax) add the non-linearity that makes networks powerful. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q3: When/why would you — Networks learn by **forward pass → loss → backprop → update**, repeated over epochs.
#
# **Answer:**
# Networks learn by **forward pass → loss → backprop → update**, repeated over epochs. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟢 Junior
# ### Q4: What is — **Adam** optimizer + right loss (cross-entropy/MSE); always **scale inputs**.
#
# **Answer:**
# **Adam** optimizer + right loss (cross-entropy/MSE); always **scale inputs**. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q5: How does — Fight overfitting with **dropout, early stopping, more data**.
#
# **Answer:**
# Fight overfitting with **dropout, early stopping, more data**. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q6: When/why would you — For **tabular data, XGBoost usually wins** — use deep learning for images/text/audio/huge data.
#
# **Answer:**
# For **tabular data, XGBoost usually wins** — use deep learning for images/text/audio/huge data. (see the Tutorial for the full explanation and code example).
