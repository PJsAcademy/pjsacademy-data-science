# %% [markdown]
# # Module 9 — Practice Project: Neural Networks: The Intuition
# ### Machine Learning Mastery — PJ's Academy
#
# ---

# %% [markdown]
# _See the course-level `projects.md` for the full project list tied to this module._
