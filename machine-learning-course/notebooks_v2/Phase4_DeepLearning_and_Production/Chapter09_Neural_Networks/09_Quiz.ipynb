# %% [markdown]
# # Module 9 Quiz — Neural Networks: The Intuition
# ### Machine Learning Mastery — PJ's Academy
#
# Read each key concept, then confirm you can restate it. Reveal cells check yourself.
#
# ---

# %% [markdown]
# ### Q1. True or False — can you explain this in your own words?
#
# > A neuron = weighted sum + **activation**; stacking many in layers learns complex patterns.

# %%
print('Self-check: re-read the Tutorial section covering — A neuron = weighted sum + **activation**; stacking many in l...')

# %% [markdown]
# ### Q2. True or False — can you explain this in your own words?
#
# > **Activations** (ReLU/sigmoid/softmax) add the non-linearity that makes networks powerful.

# %%
print('Self-check: re-read the Tutorial section covering — **Activations** (ReLU/sigmoid/softmax) add the non-linearity...')

# %% [markdown]
# ### Q3. True or False — can you explain this in your own words?
#
# > Networks learn by **forward pass → loss → backprop → update**, repeated over epochs.

# %%
print('Self-check: re-read the Tutorial section covering — Networks learn by **forward pass → loss → backprop → update*...')

# %% [markdown]
# ### Q4. True or False — can you explain this in your own words?
#
# > **Adam** optimizer + right loss (cross-entropy/MSE); always **scale inputs**.

# %%
print('Self-check: re-read the Tutorial section covering — **Adam** optimizer + right loss (cross-entropy/MSE); always ...')

# %% [markdown]
# ### Q5. True or False — can you explain this in your own words?
#
# > Fight overfitting with **dropout, early stopping, more data**.

# %%
print('Self-check: re-read the Tutorial section covering — Fight overfitting with **dropout, early stopping, more data*...')

# %% [markdown]
# ### Q6. True or False — can you explain this in your own words?
#
# > For **tabular data, XGBoost usually wins** — use deep learning for images/text/audio/huge data.

# %%
print('Self-check: re-read the Tutorial section covering — For **tabular data, XGBoost usually wins** — use deep learni...')
