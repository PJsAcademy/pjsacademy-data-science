# %% [markdown]
# # Module 10 Quiz — Machine Learning in Production
# ### Machine Learning Mastery — PJ's Academy
#
# Read each key concept, then confirm you can restate it. Reveal cells check yourself.
#
# ---

# %% [markdown]
# ### Q1. True or False — can you explain this in your own words?
#
# > Production ML = reliable serving + monitoring + retraining, not just a good test score.

# %%
print('Self-check: re-read the Tutorial section covering — Production ML = reliable serving + monitoring + retraining, ...')

# %% [markdown]
# ### Q2. True or False — can you explain this in your own words?
#
# > **Save the whole pipeline**; serve it via an **API** (FastAPI + Docker).

# %%
print('Self-check: re-read the Tutorial section covering — **Save the whole pipeline**; serve it via an **API** (FastAP...')

# %% [markdown]
# ### Q3. True or False — can you explain this in your own words?
#
# > **Drift** silently kills models — monitor inputs, predictions, and live metrics.

# %%
print('Self-check: re-read the Tutorial section covering — **Drift** silently kills models — monitor inputs, prediction...')

# %% [markdown]
# ### Q4. True or False — can you explain this in your own words?
#
# > Have a **retraining strategy** and validate challengers before promoting.

# %%
print('Self-check: re-read the Tutorial section covering — Have a **retraining strategy** and validate challengers befo...')

# %% [markdown]
# ### Q5. True or False — can you explain this in your own words?
#
# > **MLOps** brings versioning, tracking, registries, and CI/CD to ML.

# %%
print('Self-check: re-read the Tutorial section covering — **MLOps** brings versioning, tracking, registries, and CI/CD...')

# %% [markdown]
# ### Q6. True or False — can you explain this in your own words?
#
# > Build **fair, explainable** models with human oversight for high-stakes calls.

# %%
print('Self-check: re-read the Tutorial section covering — Build **fair, explainable** models with human oversight for ...')
