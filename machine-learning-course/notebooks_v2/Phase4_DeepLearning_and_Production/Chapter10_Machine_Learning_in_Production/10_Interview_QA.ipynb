# %% [markdown]
# # Module 10 — Interview Q&A: Machine Learning in Production
# ### Machine Learning Mastery — PJ's Academy

# %% [markdown]
# > **Optional Reading**
# > Interview questions for self-study — not required before the next module.
# > Return here when preparing for interviews.

# %% [markdown]
# ## 🟢 Junior
# ### Q1: What is — Production ML = reliable serving + monitoring + retraining, not just a good test score.
#
# **Answer:**
# Production ML = reliable serving + monitoring + retraining, not just a good test score. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q2: How does — **Save the whole pipeline**; serve it via an **API** (FastAPI + Docker).
#
# **Answer:**
# **Save the whole pipeline**; serve it via an **API** (FastAPI + Docker). (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q3: When/why would you — **Drift** silently kills models — monitor inputs, predictions, and live metrics.
#
# **Answer:**
# **Drift** silently kills models — monitor inputs, predictions, and live metrics. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟢 Junior
# ### Q4: What is — Have a **retraining strategy** and validate challengers before promoting.
#
# **Answer:**
# Have a **retraining strategy** and validate challengers before promoting. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q5: How does — **MLOps** brings versioning, tracking, registries, and CI/CD to ML.
#
# **Answer:**
# **MLOps** brings versioning, tracking, registries, and CI/CD to ML. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q6: When/why would you — Build **fair, explainable** models with human oversight for high-stakes calls.
#
# **Answer:**
# Build **fair, explainable** models with human oversight for high-stakes calls. (see the Tutorial for the full explanation and code example).
