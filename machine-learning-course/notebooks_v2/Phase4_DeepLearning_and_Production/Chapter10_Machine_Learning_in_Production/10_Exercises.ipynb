# %% [markdown]
# # Module 10 — Exercises: Machine Learning in Production
# ### Machine Learning Mastery — PJ's Academy
#
# Try each before checking the Tutorial.
#
# ---

# %% [markdown]
# ## Exercise 1
# Save a trained pipeline and load it in a fresh script to predict.

# %%
# your answer here

# %% [markdown]
# ## Exercise 2
# Wrap a model in a FastAPI `/predict` endpoint and test it with a sample request.

# %%
# your answer here

# %% [markdown]
# ## Exercise 3
# Simulate drift (shift a feature's mean) and describe how you'd detect it.

# %%
# your answer here

# %% [markdown]
# ## Exercise 4
# Use SHAP to explain 3 individual predictions.

# %%
# your answer here
