# %% [markdown]
# # Module 2 — Exercises: Data & Feature Engineering
# ### Machine Learning Mastery — PJ's Academy
#
# Try each before checking the Tutorial.
#
# ---

# %% [markdown]
# ## Exercise 1
# Take any CSV, run the 5 EDA commands, and write 3 things you learned.

# %%
# your answer here

# %% [markdown]
# ## Exercise 2
# One-hot encode a categorical column and ordinal-encode an ordered one. Explain why each choice.

# %%
# your answer here

# %% [markdown]
# ## Exercise 3
# Engineer 3 new features from a dataset and argue why each might help.

# %%
# your answer here

# %% [markdown]
# ## Exercise 4
# Build a `ColumnTransformer` that imputes + scales numerics and one-hots categoricals.

# %%
# your answer here
