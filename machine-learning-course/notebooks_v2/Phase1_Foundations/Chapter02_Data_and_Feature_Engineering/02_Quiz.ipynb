# %% [markdown]
# # Module 2 Quiz — Data & Feature Engineering
# ### Machine Learning Mastery — PJ's Academy
#
# Read each key concept, then confirm you can restate it. Reveal cells check yourself.
#
# ---

# %% [markdown]
# ### Q1. True or False — can you explain this in your own words?
#
# > **EDA first** — understand data before modelling.

# %%
print('Self-check: re-read the Tutorial section covering — **EDA first** — understand data before modelling....')

# %% [markdown]
# ### Q2. True or False — can you explain this in your own words?
#
# > **Impute** missing values (median/mode); fit on train only.

# %%
print('Self-check: re-read the Tutorial section covering — **Impute** missing values (median/mode); fit on train only....')

# %% [markdown]
# ### Q3. True or False — can you explain this in your own words?
#
# > **One-hot** unordered categories, **ordinal-encode** ordered ones.

# %%
print('Self-check: re-read the Tutorial section covering — **One-hot** unordered categories, **ordinal-encode** ordered...')

# %% [markdown]
# ### Q4. True or False — can you explain this in your own words?
#
# > **Scale** features for distance/gradient models; trees don't need it.

# %%
print('Self-check: re-read the Tutorial section covering — **Scale** features for distance/gradient models; trees don't...')

# %% [markdown]
# ### Q5. True or False — can you explain this in your own words?
#
# > **Feature engineering** (ratios, dates, bins) is the highest-leverage move.

# %%
print('Self-check: re-read the Tutorial section covering — **Feature engineering** (ratios, dates, bins) is the highest...')

# %% [markdown]
# ### Q6. True or False — can you explain this in your own words?
#
# > Use **pipelines** to apply steps consistently and avoid leakage.

# %%
print('Self-check: re-read the Tutorial section covering — Use **pipelines** to apply steps consistently and avoid leak...')
