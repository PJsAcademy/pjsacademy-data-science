# %% [markdown]
# # Module 2 — Interview Q&A: Data & Feature Engineering
# ### Machine Learning Mastery — PJ's Academy

# %% [markdown]
# > **Optional Reading**
# > Interview questions for self-study — not required before the next module.
# > Return here when preparing for interviews.

# %% [markdown]
# ## 🟢 Junior
# ### Q1: What is — **EDA first** — understand data before modelling.
#
# **Answer:**
# **EDA first** — understand data before modelling. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q2: How does — **Impute** missing values (median/mode); fit on train only.
#
# **Answer:**
# **Impute** missing values (median/mode); fit on train only. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q3: When/why would you — **One-hot** unordered categories, **ordinal-encode** ordered ones.
#
# **Answer:**
# **One-hot** unordered categories, **ordinal-encode** ordered ones. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟢 Junior
# ### Q4: What is — **Scale** features for distance/gradient models; trees don't need it.
#
# **Answer:**
# **Scale** features for distance/gradient models; trees don't need it. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q5: How does — **Feature engineering** (ratios, dates, bins) is the highest-leverage move.
#
# **Answer:**
# **Feature engineering** (ratios, dates, bins) is the highest-leverage move. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q6: When/why would you — Use **pipelines** to apply steps consistently and avoid leakage.
#
# **Answer:**
# Use **pipelines** to apply steps consistently and avoid leakage. (see the Tutorial for the full explanation and code example).
