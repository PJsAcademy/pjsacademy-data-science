# %% [markdown]
# # Module 1 Quiz — What Machine Learning Really Is
# ### Machine Learning Mastery — PJ's Academy
#
# Read each key concept, then confirm you can restate it. Reveal cells check yourself.
#
# ---

# %% [markdown]
# ### Q1. True or False — can you explain this in your own words?
#
# > ML learns **rules from examples** instead of you writing them.

# %%
print('Self-check: re-read the Tutorial section covering — ML learns **rules from examples** instead of you writing the...')

# %% [markdown]
# ### Q2. True or False — can you explain this in your own words?
#
# > **Supervised** (labelled) = regression (numbers) + classification (categories); **unsupervised** finds structure.

# %%
print('Self-check: re-read the Tutorial section covering — **Supervised** (labelled) = regression (numbers) + classific...')

# %% [markdown]
# ### Q3. True or False — can you explain this in your own words?
#
# > Always **train/test split** — test performance is the only honest measure.

# %%
print('Self-check: re-read the Tutorial section covering — Always **train/test split** — test performance is the only h...')

# %% [markdown]
# ### Q4. True or False — can you explain this in your own words?
#
# > **Data leakage** silently inflates scores — protect the test set.

# %%
print('Self-check: re-read the Tutorial section covering — **Data leakage** silently inflates scores — protect the test...')

# %% [markdown]
# ### Q5. True or False — can you explain this in your own words?
#
# > The game is balancing **underfitting vs overfitting**.

# %%
print('Self-check: re-read the Tutorial section covering — The game is balancing **underfitting vs overfitting**....')

# %% [markdown]
# ### Q6. True or False — can you explain this in your own words?
#
# > Follow the **8-step workflow** every time.

# %%
print('Self-check: re-read the Tutorial section covering — Follow the **8-step workflow** every time....')
