# %% [markdown]
# # Module 1 — Interview Q&A: What Machine Learning Really Is
# ### Machine Learning Mastery — PJ's Academy

# %% [markdown]
# > **Optional Reading**
# > Interview questions for self-study — not required before the next module.
# > Return here when preparing for interviews.

# %% [markdown]
# ## 🟢 Junior
# ### Q1: What is — ML learns **rules from examples** instead of you writing them.
#
# **Answer:**
# ML learns **rules from examples** instead of you writing them. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q2: How does — **Supervised** (labelled) = regression (numbers) + classification (categories); **unsupervised** finds structure.
#
# **Answer:**
# **Supervised** (labelled) = regression (numbers) + classification (categories); **unsupervised** finds structure. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q3: When/why would you — Always **train/test split** — test performance is the only honest measure.
#
# **Answer:**
# Always **train/test split** — test performance is the only honest measure. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟢 Junior
# ### Q4: What is — **Data leakage** silently inflates scores — protect the test set.
#
# **Answer:**
# **Data leakage** silently inflates scores — protect the test set. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q5: How does — The game is balancing **underfitting vs overfitting**.
#
# **Answer:**
# The game is balancing **underfitting vs overfitting**. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q6: When/why would you — Follow the **8-step workflow** every time.
#
# **Answer:**
# Follow the **8-step workflow** every time. (see the Tutorial for the full explanation and code example).
