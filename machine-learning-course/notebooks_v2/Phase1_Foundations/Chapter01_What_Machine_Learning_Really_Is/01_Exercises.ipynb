# %% [markdown]
# # Module 1 — Exercises: What Machine Learning Really Is
# ### Machine Learning Mastery — PJ's Academy
#
# Try each before checking the Tutorial.
#
# ---

# %% [markdown]
# ## Exercise 1
# For each, say regression or classification: predicting tomorrow's temperature; whether a transaction is fraud; a house's price; a tumour's type.

# %%
# your answer here

# %% [markdown]
# ## Exercise 2
# In your own words, explain overfitting to a 12-year-old using an analogy.

# %%
# your answer here

# %% [markdown]
# ## Exercise 3
# Why is it cheating to evaluate on training data? Explain in 2 sentences.

# %%
# your answer here
