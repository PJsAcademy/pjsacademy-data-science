# %% [markdown]
# # Module 5 Quiz — Ensembles: The Models That Win
# ### Machine Learning Mastery — PJ's Academy
#
# Read each key concept, then confirm you can restate it. Reveal cells check yourself.
#
# ---

# %% [markdown]
# ### Q1. True or False — can you explain this in your own words?
#
# > Ensembles combine many models so errors cancel — the best tabular approach.

# %%
print('Self-check: re-read the Tutorial section covering — Ensembles combine many models so errors cancel — the best ta...')

# %% [markdown]
# ### Q2. True or False — can you explain this in your own words?
#
# > **Bagging (Random Forest)** cuts variance; **Boosting (XGBoost)** cuts bias.

# %%
print('Self-check: re-read the Tutorial section covering — **Bagging (Random Forest)** cuts variance; **Boosting (XGBoo...')

# %% [markdown]
# ### Q3. True or False — can you explain this in your own words?
#
# > **Random Forest** = robust default, feature importance, no scaling.

# %%
print('Self-check: re-read the Tutorial section covering — **Random Forest** = robust default, feature importance, no s...')

# %% [markdown]
# ### Q4. True or False — can you explain this in your own words?
#
# > **XGBoost/LightGBM** = usually the most accurate; tune `learning_rate` + `n_estimators` + `max_depth`.

# %%
print('Self-check: re-read the Tutorial section covering — **XGBoost/LightGBM** = usually the most accurate; tune `lear...')

# %% [markdown]
# ### Q5. True or False — can you explain this in your own words?
#
# > Use **early stopping** and row/feature **subsampling** to control overfitting.

# %%
print('Self-check: re-read the Tutorial section covering — Use **early stopping** and row/feature **subsampling** to co...')

# %% [markdown]
# ### Q6. True or False — can you explain this in your own words?
#
# > **Stacking** squeezes out the last bit of performance.

# %%
print('Self-check: re-read the Tutorial section covering — **Stacking** squeezes out the last bit of performance....')
