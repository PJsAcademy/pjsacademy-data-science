# %% [markdown]
# # Module 5 — Interview Q&A: Ensembles: The Models That Win
# ### Machine Learning Mastery — PJ's Academy

# %% [markdown]
# > **Optional Reading**
# > Interview questions for self-study — not required before the next module.
# > Return here when preparing for interviews.

# %% [markdown]
# ## 🟢 Junior
# ### Q1: What is — Ensembles combine many models so errors cancel — the best tabular approach.
#
# **Answer:**
# Ensembles combine many models so errors cancel — the best tabular approach. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q2: How does — **Bagging (Random Forest)** cuts variance; **Boosting (XGBoost)** cuts bias.
#
# **Answer:**
# **Bagging (Random Forest)** cuts variance; **Boosting (XGBoost)** cuts bias. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q3: When/why would you — **Random Forest** = robust default, feature importance, no scaling.
#
# **Answer:**
# **Random Forest** = robust default, feature importance, no scaling. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟢 Junior
# ### Q4: What is — **XGBoost/LightGBM** = usually the most accurate; tune `learning_rate` + `n_estimators` + `max_depth`.
#
# **Answer:**
# **XGBoost/LightGBM** = usually the most accurate; tune `learning_rate` + `n_estimators` + `max_depth`. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q5: How does — Use **early stopping** and row/feature **subsampling** to control overfitting.
#
# **Answer:**
# Use **early stopping** and row/feature **subsampling** to control overfitting. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q6: When/why would you — **Stacking** squeezes out the last bit of performance.
#
# **Answer:**
# **Stacking** squeezes out the last bit of performance. (see the Tutorial for the full explanation and code example).
