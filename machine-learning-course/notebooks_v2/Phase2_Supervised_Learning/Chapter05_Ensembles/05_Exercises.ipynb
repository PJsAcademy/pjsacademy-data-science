# %% [markdown]
# # Module 5 — Exercises: Ensembles: The Models That Win
# ### Machine Learning Mastery — PJ's Academy
#
# Try each before checking the Tutorial.
#
# ---

# %% [markdown]
# ## Exercise 1
# Train Random Forest and XGBoost on the same data; compare ROC-AUC.

# %%
# your answer here

# %% [markdown]
# ## Exercise 2
# Plot the top-10 feature importances from a Random Forest.

# %%
# your answer here

# %% [markdown]
# ## Exercise 3
# Sweep XGBoost `learning_rate` (0.3, 0.1, 0.05) with matching `n_estimators`; observe accuracy vs time.

# %%
# your answer here
