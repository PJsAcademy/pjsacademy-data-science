# %% [markdown]
# # Module 4 — Exercises: Classification: Predicting Categories
# ### Machine Learning Mastery — PJ's Academy
#
# Try each before checking the Tutorial.
#
# ---

# %% [markdown]
# ## Exercise 1
# Train Logistic Regression + a Decision Tree on the same data; compare F1 and ROC-AUC.

# %%
# your answer here

# %% [markdown]
# ## Exercise 2
# Print a confusion matrix and explain each cell (TP/FP/FN/TN) in words.

# %%
# your answer here

# %% [markdown]
# ## Exercise 3
# Lower the threshold to 0.3 and describe what happens to precision vs recall.

# %%
# your answer here

# %% [markdown]
# ## Exercise 4
# On an imbalanced dataset, compare accuracy vs F1 — show why accuracy misleads.

# %%
# your answer here
