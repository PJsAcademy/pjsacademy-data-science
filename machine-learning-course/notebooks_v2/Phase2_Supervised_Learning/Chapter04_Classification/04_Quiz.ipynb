# %% [markdown]
# # Module 4 Quiz — Classification: Predicting Categories
# ### Machine Learning Mastery — PJ's Academy
#
# Read each key concept, then confirm you can restate it. Reveal cells check yourself.
#
# ---

# %% [markdown]
# ### Q1. True or False — can you explain this in your own words?
#
# > Classification predicts a **category**, usually via a **probability** you threshold.

# %%
print('Self-check: re-read the Tutorial section covering — Classification predicts a **category**, usually via a **prob...')

# %% [markdown]
# ### Q2. True or False — can you explain this in your own words?
#
# > **Logistic Regression** = sigmoid over a linear score; strong interpretable baseline.

# %%
print('Self-check: re-read the Tutorial section covering — **Logistic Regression** = sigmoid over a linear score; stron...')

# %% [markdown]
# ### Q3. True or False — can you explain this in your own words?
#
# > **kNN** (scale it!), **Naive Bayes** (text), **Decision Trees** (readable, limit depth).

# %%
print('Self-check: re-read the Tutorial section covering — **kNN** (scale it!), **Naive Bayes** (text), **Decision Tree...')

# %% [markdown]
# ### Q4. True or False — can you explain this in your own words?
#
# > **Accuracy lies on imbalanced data** — use the **confusion matrix**, precision, recall, F1, ROC-AUC.

# %%
print('Self-check: re-read the Tutorial section covering — **Accuracy lies on imbalanced data** — use the **confusion m...')

# %% [markdown]
# ### Q5. True or False — can you explain this in your own words?
#
# > Trade **precision vs recall** by the threshold, based on business cost.

# %%
print('Self-check: re-read the Tutorial section covering — Trade **precision vs recall** by the threshold, based on bus...')

# %% [markdown]
# ### Q6. True or False — can you explain this in your own words?
#
# > Handle **imbalance** with class weights / resampling and the right metrics.

# %%
print('Self-check: re-read the Tutorial section covering — Handle **imbalance** with class weights / resampling and the...')
