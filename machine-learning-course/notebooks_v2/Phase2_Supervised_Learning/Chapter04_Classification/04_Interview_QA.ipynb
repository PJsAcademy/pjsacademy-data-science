# %% [markdown]
# # Module 4 — Interview Q&A: Classification: Predicting Categories
# ### Machine Learning Mastery — PJ's Academy

# %% [markdown]
# > **Optional Reading**
# > Interview questions for self-study — not required before the next module.
# > Return here when preparing for interviews.

# %% [markdown]
# ## 🟢 Junior
# ### Q1: What is — Classification predicts a **category**, usually via a **probability** you threshold.
#
# **Answer:**
# Classification predicts a **category**, usually via a **probability** you threshold. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q2: How does — **Logistic Regression** = sigmoid over a linear score; strong interpretable baseline.
#
# **Answer:**
# **Logistic Regression** = sigmoid over a linear score; strong interpretable baseline. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q3: When/why would you — **kNN** (scale it!), **Naive Bayes** (text), **Decision Trees** (readable, limit depth).
#
# **Answer:**
# **kNN** (scale it!), **Naive Bayes** (text), **Decision Trees** (readable, limit depth). (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟢 Junior
# ### Q4: What is — **Accuracy lies on imbalanced data** — use the **confusion matrix**, precision, recall, F1, ROC-AUC.
#
# **Answer:**
# **Accuracy lies on imbalanced data** — use the **confusion matrix**, precision, recall, F1, ROC-AUC. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q5: How does — Trade **precision vs recall** by the threshold, based on business cost.
#
# **Answer:**
# Trade **precision vs recall** by the threshold, based on business cost. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q6: When/why would you — Handle **imbalance** with class weights / resampling and the right metrics.
#
# **Answer:**
# Handle **imbalance** with class weights / resampling and the right metrics. (see the Tutorial for the full explanation and code example).
