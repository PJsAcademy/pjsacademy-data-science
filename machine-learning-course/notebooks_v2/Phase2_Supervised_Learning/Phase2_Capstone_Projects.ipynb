# %% [markdown]
# # Phase2 Supervised Learning — Capstone
#
# Combine concepts from:
#
# | Topic | Module |
# |---|---|
# | Regression: Predicting Numbers | Module 3 |
# | Classification: Predicting Categories | Module 4 |
# | Ensembles: The Models That Win | Module 5 |
# | Evaluation: Trusting Your Model | Module 6 |
#
# ## Capstone Project
# Build an end-to-end mini-project that uses every module in this phase together. See the course's `projects.md` for a full project matched to this phase's difficulty.
