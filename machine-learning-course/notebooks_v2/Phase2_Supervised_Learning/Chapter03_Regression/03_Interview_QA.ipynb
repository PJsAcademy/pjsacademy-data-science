# %% [markdown]
# # Module 3 — Interview Q&A: Regression: Predicting Numbers
# ### Machine Learning Mastery — PJ's Academy

# %% [markdown]
# > **Optional Reading**
# > Interview questions for self-study — not required before the next module.
# > Return here when preparing for interviews.

# %% [markdown]
# ## 🟢 Junior
# ### Q1: What is — Regression fits `y = w·x + b`; training minimizes **MSE**.
#
# **Answer:**
# Regression fits `y = w·x + b`; training minimizes **MSE**. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q2: How does — Evaluate with **RMSE/MAE** (error size) and **R²** (variance explained).
#
# **Answer:**
# Evaluate with **RMSE/MAE** (error size) and **R²** (variance explained). (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q3: When/why would you — **Polynomial features** let linear models fit curves — but overfit if too high.
#
# **Answer:**
# **Polynomial features** let linear models fit curves — but overfit if too high. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟢 Junior
# ### Q4: What is — **Regularization** (Ridge/Lasso) fights overfitting; Lasso also selects features.
#
# **Answer:**
# **Regularization** (Ridge/Lasso) fights overfitting; Lasso also selects features. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q5: How does — **Scale features** before regularized models.
#
# **Answer:**
# **Scale features** before regularized models. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q6: When/why would you — **Residual plots** reveal what the model is missing. Always start with a simple baseline.
#
# **Answer:**
# **Residual plots** reveal what the model is missing. Always start with a simple baseline. (see the Tutorial for the full explanation and code example).
