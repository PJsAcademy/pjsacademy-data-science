# %% [markdown]
# # Module 3 Quiz — Regression: Predicting Numbers
# ### Machine Learning Mastery — PJ's Academy
#
# Read each key concept, then confirm you can restate it. Reveal cells check yourself.
#
# ---

# %% [markdown]
# ### Q1. True or False — can you explain this in your own words?
#
# > Regression fits `y = w·x + b`; training minimizes **MSE**.

# %%
print('Self-check: re-read the Tutorial section covering — Regression fits `y = w·x + b`; training minimizes **MSE**....')

# %% [markdown]
# ### Q2. True or False — can you explain this in your own words?
#
# > Evaluate with **RMSE/MAE** (error size) and **R²** (variance explained).

# %%
print('Self-check: re-read the Tutorial section covering — Evaluate with **RMSE/MAE** (error size) and **R²** (variance...')

# %% [markdown]
# ### Q3. True or False — can you explain this in your own words?
#
# > **Polynomial features** let linear models fit curves — but overfit if too high.

# %%
print('Self-check: re-read the Tutorial section covering — **Polynomial features** let linear models fit curves — but o...')

# %% [markdown]
# ### Q4. True or False — can you explain this in your own words?
#
# > **Regularization** (Ridge/Lasso) fights overfitting; Lasso also selects features.

# %%
print('Self-check: re-read the Tutorial section covering — **Regularization** (Ridge/Lasso) fights overfitting; Lasso a...')

# %% [markdown]
# ### Q5. True or False — can you explain this in your own words?
#
# > **Scale features** before regularized models.

# %%
print('Self-check: re-read the Tutorial section covering — **Scale features** before regularized models....')

# %% [markdown]
# ### Q6. True or False — can you explain this in your own words?
#
# > **Residual plots** reveal what the model is missing. Always start with a simple baseline.

# %%
print('Self-check: re-read the Tutorial section covering — **Residual plots** reveal what the model is missing. Always ...')
