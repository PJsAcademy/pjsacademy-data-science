# %% [markdown]
# # Module 3 — Exercises: Regression: Predicting Numbers
# ### Machine Learning Mastery — PJ's Academy
#
# Try each before checking the Tutorial.
#
# ---

# %% [markdown]
# ## Exercise 1
# Train `LinearRegression` on any numeric dataset; report RMSE and R².

# %%
# your answer here

# %% [markdown]
# ## Exercise 2
# Add `PolynomialFeatures(degree=2)` — does test R² improve or overfit?

# %%
# your answer here

# %% [markdown]
# ## Exercise 3
# Compare Ridge with `alpha=0.1, 1, 10`. Plot how coefficients shrink.

# %%
# your answer here

# %% [markdown]
# ## Exercise 4
# Make a residual plot and interpret it — is the linear assumption OK?

# %%
# your answer here
