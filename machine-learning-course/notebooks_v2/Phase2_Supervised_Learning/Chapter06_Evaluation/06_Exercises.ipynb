# %% [markdown]
# # Module 6 — Exercises: Evaluation: Trusting Your Model
# ### Machine Learning Mastery — PJ's Academy
#
# Try each before checking the Tutorial.
#
# ---

# %% [markdown]
# ## Exercise 1
# Run 5-fold cross-validation and report mean ± std. Compare to a single split.

# %%
# your answer here

# %% [markdown]
# ## Exercise 2
# Plot a learning curve and diagnose bias vs variance.

# %%
# your answer here

# %% [markdown]
# ## Exercise 3
# Deliberately leak (scale before splitting), then do it correctly — compare the scores.

# %%
# your answer here

# %% [markdown]
# ## Exercise 4
# For 3 scenarios (fraud, spam, tumour screening), pick the metric to optimize and justify it.

# %%
# your answer here
