# %% [markdown]
# # Module 6 Quiz — Evaluation: Trusting Your Model
# ### Machine Learning Mastery — PJ's Academy
#
# Read each key concept, then confirm you can restate it. Reveal cells check yourself.
#
# ---

# %% [markdown]
# ### Q1. True or False — can you explain this in your own words?
#
# > Judge only on **unseen data**; use **cross-validation** for stable estimates.

# %%
print('Self-check: re-read the Tutorial section covering — Judge only on **unseen data**; use **cross-validation** for ...')

# %% [markdown]
# ### Q2. True or False — can you explain this in your own words?
#
# > Error = **bias + variance**; diagnose with learning curves and fix accordingly.

# %%
print('Self-check: re-read the Tutorial section covering — Error = **bias + variance**; diagnose with learning curves a...')

# %% [markdown]
# ### Q3. True or False — can you explain this in your own words?
#
# > Pick the **metric that matches the cost** — accuracy lies on imbalanced data.

# %%
print('Self-check: re-read the Tutorial section covering — Pick the **metric that matches the cost** — accuracy lies on...')

# %% [markdown]
# ### Q4. True or False — can you explain this in your own words?
#
# > Use a **train/validation/test** split (or CV + final test) so tuning doesn't corrupt your estimate.

# %%
print('Self-check: re-read the Tutorial section covering — Use a **train/validation/test** split (or CV + final test) s...')

# %% [markdown]
# ### Q5. True or False — can you explain this in your own words?
#
# > **Leakage** is the silent killer — fit preprocessing on train only.

# %%
print('Self-check: re-read the Tutorial section covering — **Leakage** is the silent killer — fit preprocessing on trai...')

# %% [markdown]
# ### Q6. True or False — can you explain this in your own words?
#
# > Look **beyond one number**: confusion matrix, calibration, error analysis, per-slice metrics.

# %%
print('Self-check: re-read the Tutorial section covering — Look **beyond one number**: confusion matrix, calibration, e...')
