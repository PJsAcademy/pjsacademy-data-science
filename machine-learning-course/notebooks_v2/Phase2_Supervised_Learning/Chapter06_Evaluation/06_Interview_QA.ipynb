# %% [markdown]
# # Module 6 — Interview Q&A: Evaluation: Trusting Your Model
# ### Machine Learning Mastery — PJ's Academy

# %% [markdown]
# > **Optional Reading**
# > Interview questions for self-study — not required before the next module.
# > Return here when preparing for interviews.

# %% [markdown]
# ## 🟢 Junior
# ### Q1: What is — Judge only on **unseen data**; use **cross-validation** for stable estimates.
#
# **Answer:**
# Judge only on **unseen data**; use **cross-validation** for stable estimates. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q2: How does — Error = **bias + variance**; diagnose with learning curves and fix accordingly.
#
# **Answer:**
# Error = **bias + variance**; diagnose with learning curves and fix accordingly. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q3: When/why would you — Pick the **metric that matches the cost** — accuracy lies on imbalanced data.
#
# **Answer:**
# Pick the **metric that matches the cost** — accuracy lies on imbalanced data. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟢 Junior
# ### Q4: What is — Use a **train/validation/test** split (or CV + final test) so tuning doesn't corrupt your estimate.
#
# **Answer:**
# Use a **train/validation/test** split (or CV + final test) so tuning doesn't corrupt your estimate. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q5: How does — **Leakage** is the silent killer — fit preprocessing on train only.
#
# **Answer:**
# **Leakage** is the silent killer — fit preprocessing on train only. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q6: When/why would you — Look **beyond one number**: confusion matrix, calibration, error analysis, per-slice metrics.
#
# **Answer:**
# Look **beyond one number**: confusion matrix, calibration, error analysis, per-slice metrics. (see the Tutorial for the full explanation and code example).
