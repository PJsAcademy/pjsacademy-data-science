# %% [markdown]
# # Module 7 — Exercises: Unsupervised Learning: Finding Hidden Structure
# ### Machine Learning Mastery — PJ's Academy
#
# Try each before checking the Tutorial.
#
# ---

# %% [markdown]
# ## Exercise 1
# Cluster a dataset with K-Means; use the elbow method to choose k; describe each cluster.

# %%
# your answer here

# %% [markdown]
# ## Exercise 2
# Run PCA to 2 components and scatter-plot; how much variance is retained?

# %%
# your answer here

# %% [markdown]
# ## Exercise 3
# Use IsolationForest to flag the top 2% anomalies and inspect them.

# %%
# your answer here

# %% [markdown]
# ## Exercise 4
# Compare K-Means vs DBSCAN on data with non-round clusters.

# %%
# your answer here
