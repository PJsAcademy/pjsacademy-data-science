# %% [markdown]
# # Module 7 Quiz — Unsupervised Learning: Finding Hidden Structure
# ### Machine Learning Mastery — PJ's Academy
#
# Read each key concept, then confirm you can restate it. Reveal cells check yourself.
#
# ---

# %% [markdown]
# ### Q1. True or False — can you explain this in your own words?
#
# > Unsupervised learning finds **structure without labels** — clustering and dimensionality reduction.

# %%
print('Self-check: re-read the Tutorial section covering — Unsupervised learning finds **structure without labels** — c...')

# %% [markdown]
# ### Q2. True or False — can you explain this in your own words?
#
# > **K-Means** groups by nearest centre; **scale first**, pick k with the elbow/silhouette.

# %%
print('Self-check: re-read the Tutorial section covering — **K-Means** groups by nearest centre; **scale first**, pick ...')

# %% [markdown]
# ### Q3. True or False — can you explain this in your own words?
#
# > **DBSCAN/hierarchical** handle non-round clusters and unknown k.

# %%
print('Self-check: re-read the Tutorial section covering — **DBSCAN/hierarchical** handle non-round clusters and unknow...')

# %% [markdown]
# ### Q4. True or False — can you explain this in your own words?
#
# > **PCA** compresses correlated features while keeping variance — for speed, denoising, and visualization.

# %%
print('Self-check: re-read the Tutorial section covering — **PCA** compresses correlated features while keeping varianc...')

# %% [markdown]
# ### Q5. True or False — can you explain this in your own words?
#
# > **t-SNE/UMAP** are for plots only, not model inputs.

# %%
print('Self-check: re-read the Tutorial section covering — **t-SNE/UMAP** are for plots only, not model inputs....')

# %% [markdown]
# ### Q6. True or False — can you explain this in your own words?
#
# > Evaluate with silhouette/explained variance — but **business usefulness** is the real test.

# %%
print('Self-check: re-read the Tutorial section covering — Evaluate with silhouette/explained variance — but **business...')
