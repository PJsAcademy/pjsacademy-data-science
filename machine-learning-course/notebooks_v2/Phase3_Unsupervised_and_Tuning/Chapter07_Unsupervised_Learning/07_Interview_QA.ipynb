# %% [markdown]
# # Module 7 — Interview Q&A: Unsupervised Learning: Finding Hidden Structure
# ### Machine Learning Mastery — PJ's Academy

# %% [markdown]
# > **Optional Reading**
# > Interview questions for self-study — not required before the next module.
# > Return here when preparing for interviews.

# %% [markdown]
# ## 🟢 Junior
# ### Q1: What is — Unsupervised learning finds **structure without labels** — clustering and dimensionality reduction.
#
# **Answer:**
# Unsupervised learning finds **structure without labels** — clustering and dimensionality reduction. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q2: How does — **K-Means** groups by nearest centre; **scale first**, pick k with the elbow/silhouette.
#
# **Answer:**
# **K-Means** groups by nearest centre; **scale first**, pick k with the elbow/silhouette. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q3: When/why would you — **DBSCAN/hierarchical** handle non-round clusters and unknown k.
#
# **Answer:**
# **DBSCAN/hierarchical** handle non-round clusters and unknown k. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟢 Junior
# ### Q4: What is — **PCA** compresses correlated features while keeping variance — for speed, denoising, and visualization.
#
# **Answer:**
# **PCA** compresses correlated features while keeping variance — for speed, denoising, and visualization. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q5: How does — **t-SNE/UMAP** are for plots only, not model inputs.
#
# **Answer:**
# **t-SNE/UMAP** are for plots only, not model inputs. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q6: When/why would you — Evaluate with silhouette/explained variance — but **business usefulness** is the real test.
#
# **Answer:**
# Evaluate with silhouette/explained variance — but **business usefulness** is the real test. (see the Tutorial for the full explanation and code example).
