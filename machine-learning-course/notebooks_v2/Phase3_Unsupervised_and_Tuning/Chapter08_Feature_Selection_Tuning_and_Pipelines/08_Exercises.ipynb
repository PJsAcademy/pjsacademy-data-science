# %% [markdown]
# # Module 8 — Exercises: Feature Selection, Tuning & Pipelines
# ### Machine Learning Mastery — PJ's Academy
#
# Try each before checking the Tutorial.
#
# ---

# %% [markdown]
# ## Exercise 1
# Run GridSearchCV over 2–3 hyperparameters; report best params and CV score.

# %%
# your answer here

# %% [markdown]
# ## Exercise 2
# Compare grid vs random search speed and result on the same model.

# %%
# your answer here

# %% [markdown]
# ## Exercise 3
# Wrap a scaler + model in a Pipeline and tune with the `model__` prefix.

# %%
# your answer here

# %% [markdown]
# ## Exercise 4
# (Bonus) Use Optuna for 30 trials on XGBoost; beat your grid-search score.

# %%
# your answer here
