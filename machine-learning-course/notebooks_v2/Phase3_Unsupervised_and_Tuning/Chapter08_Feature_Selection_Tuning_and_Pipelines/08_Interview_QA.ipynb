# %% [markdown]
# # Module 8 — Interview Q&A: Feature Selection, Tuning & Pipelines
# ### Machine Learning Mastery — PJ's Academy

# %% [markdown]
# > **Optional Reading**
# > Interview questions for self-study — not required before the next module.
# > Return here when preparing for interviews.

# %% [markdown]
# ## 🟢 Junior
# ### Q1: What is — **Feature selection** (filter, model-based, RFE) cuts noise and overfitting.
#
# **Answer:**
# **Feature selection** (filter, model-based, RFE) cuts noise and overfitting. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q2: How does — **Tuning** = searching hyperparameters: **grid** (small spaces), **random** (bigger), **Bayesian/Optuna** (best).
#
# **Answer:**
# **Tuning** = searching hyperparameters: **grid** (small spaces), **random** (bigger), **Bayesian/Optuna** (best). (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q3: When/why would you — Tune only the **high-impact hyperparameters** per model.
#
# **Answer:**
# Tune only the **high-impact hyperparameters** per model. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟢 Junior
# ### Q4: What is — Use **Pipelines** so preprocessing is tuned/CV'd without leakage.
#
# **Answer:**
# Use **Pipelines** so preprocessing is tuned/CV'd without leakage. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q5: How does — **Fix features before you tune** — engineering usually beats optimization.
#
# **Answer:**
# **Fix features before you tune** — engineering usually beats optimization. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q6: When/why would you — Confirm the final model on the **untouched test set**.
#
# **Answer:**
# Confirm the final model on the **untouched test set**. (see the Tutorial for the full explanation and code example).
