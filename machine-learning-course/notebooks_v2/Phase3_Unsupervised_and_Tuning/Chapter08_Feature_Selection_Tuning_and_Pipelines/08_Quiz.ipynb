# %% [markdown]
# # Module 8 Quiz — Feature Selection, Tuning & Pipelines
# ### Machine Learning Mastery — PJ's Academy
#
# Read each key concept, then confirm you can restate it. Reveal cells check yourself.
#
# ---

# %% [markdown]
# ### Q1. True or False — can you explain this in your own words?
#
# > **Feature selection** (filter, model-based, RFE) cuts noise and overfitting.

# %%
print('Self-check: re-read the Tutorial section covering — **Feature selection** (filter, model-based, RFE) cuts noise ...')

# %% [markdown]
# ### Q2. True or False — can you explain this in your own words?
#
# > **Tuning** = searching hyperparameters: **grid** (small spaces), **random** (bigger), **Bayesian/Optuna** (best).

# %%
print('Self-check: re-read the Tutorial section covering — **Tuning** = searching hyperparameters: **grid** (small spac...')

# %% [markdown]
# ### Q3. True or False — can you explain this in your own words?
#
# > Tune only the **high-impact hyperparameters** per model.

# %%
print('Self-check: re-read the Tutorial section covering — Tune only the **high-impact hyperparameters** per model....')

# %% [markdown]
# ### Q4. True or False — can you explain this in your own words?
#
# > Use **Pipelines** so preprocessing is tuned/CV'd without leakage.

# %%
print('Self-check: re-read the Tutorial section covering — Use **Pipelines** so preprocessing is tuned/CV'd without lea...')

# %% [markdown]
# ### Q5. True or False — can you explain this in your own words?
#
# > **Fix features before you tune** — engineering usually beats optimization.

# %%
print('Self-check: re-read the Tutorial section covering — **Fix features before you tune** — engineering usually beats...')

# %% [markdown]
# ### Q6. True or False — can you explain this in your own words?
#
# > Confirm the final model on the **untouched test set**.

# %%
print('Self-check: re-read the Tutorial section covering — Confirm the final model on the **untouched test set**....')
