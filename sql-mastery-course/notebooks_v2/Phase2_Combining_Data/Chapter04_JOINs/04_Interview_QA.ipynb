# %% [markdown]
# # Module 4 — Interview Q&A: JOINs: Combining Tables
# ### SQL Mastery — PJ's Academy

# %% [markdown]
# > **Optional Reading**
# > Interview questions for self-study — not required before the next module.
# > Return here when preparing for interviews.

# %% [markdown]
# ## 🟢 Junior
# ### Q1: What is — Tables are split to avoid repetition; **JOINs recombine them** via key columns.
#
# **Answer:**
# Tables are split to avoid repetition; **JOINs recombine them** via key columns. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q2: How does — `INNER JOIN` keeps only matches; `LEFT JOIN` keeps all left rows (+NULLs for non-matches).
#
# **Answer:**
# `INNER JOIN` keeps only matches; `LEFT JOIN` keeps all left rows (+NULLs for non-matches). (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q3: When/why would you — **Anti-join** = `LEFT JOIN … WHERE right.key IS NULL` → "rows with no match".
#
# **Answer:**
# **Anti-join** = `LEFT JOIN … WHERE right.key IS NULL` → "rows with no match". (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟢 Junior
# ### Q4: What is — Chain joins for 3+ tables; use a **self join** for within-table relationships (employee↔manager).
#
# **Answer:**
# Chain joins for 3+ tables; use a **self join** for within-table relationships (employee↔manager). (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q5: How does — **JOIN + GROUP BY** powers most analytics.
#
# **Answer:**
# **JOIN + GROUP BY** powers most analytics. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q6: When/why would you — Qualify columns (`e.dept_id`), pick the right join type, and beware double-counting.
#
# **Answer:**
# Qualify columns (`e.dept_id`), pick the right join type, and beware double-counting. (see the Tutorial for the full explanation and code example).
