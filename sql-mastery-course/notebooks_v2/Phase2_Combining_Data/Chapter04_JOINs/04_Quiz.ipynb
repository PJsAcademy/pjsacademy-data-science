# %% [markdown]
# # Module 4 Quiz — JOINs: Combining Tables
# ### SQL Mastery — PJ's Academy
#
# Read each key concept, then confirm you can restate it. Reveal cells check yourself.
#
# ---

# %% [markdown]
# ### Q1. True or False — can you explain this in your own words?
#
# > Tables are split to avoid repetition; **JOINs recombine them** via key columns.

# %%
print('Self-check: re-read the Tutorial section covering — Tables are split to avoid repetition; **JOINs recombine them...')

# %% [markdown]
# ### Q2. True or False — can you explain this in your own words?
#
# > `INNER JOIN` keeps only matches; `LEFT JOIN` keeps all left rows (+NULLs for non-matches).

# %%
print('Self-check: re-read the Tutorial section covering — `INNER JOIN` keeps only matches; `LEFT JOIN` keeps all left ...')

# %% [markdown]
# ### Q3. True or False — can you explain this in your own words?
#
# > **Anti-join** = `LEFT JOIN … WHERE right.key IS NULL` → "rows with no match".

# %%
print('Self-check: re-read the Tutorial section covering — **Anti-join** = `LEFT JOIN … WHERE right.key IS NULL` → "row...')

# %% [markdown]
# ### Q4. True or False — can you explain this in your own words?
#
# > Chain joins for 3+ tables; use a **self join** for within-table relationships (employee↔manager).

# %%
print('Self-check: re-read the Tutorial section covering — Chain joins for 3+ tables; use a **self join** for within-ta...')

# %% [markdown]
# ### Q5. True or False — can you explain this in your own words?
#
# > **JOIN + GROUP BY** powers most analytics.

# %%
print('Self-check: re-read the Tutorial section covering — **JOIN + GROUP BY** powers most analytics....')

# %% [markdown]
# ### Q6. True or False — can you explain this in your own words?
#
# > Qualify columns (`e.dept_id`), pick the right join type, and beware double-counting.

# %%
print('Self-check: re-read the Tutorial section covering — Qualify columns (`e.dept_id`), pick the right join type, and...')
