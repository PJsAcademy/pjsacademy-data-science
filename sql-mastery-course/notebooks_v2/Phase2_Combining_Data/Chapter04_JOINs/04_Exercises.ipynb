# %% [markdown]
# # Module 4 — Exercises: JOINs: Combining Tables
# ### SQL Mastery — PJ's Academy
#
# Try each before checking the Tutorial.
#
# ---

# %% [markdown]
# ## Exercise 1
# List each employee with their department name (INNER JOIN).

# %%
# your answer here

# %% [markdown]
# ## Exercise 2
# List all departments and their employees, including empty departments (LEFT JOIN).

# %%
# your answer here

# %% [markdown]
# ## Exercise 3
# Find customers who never placed an order (anti-join).

# %%
# your answer here

# %% [markdown]
# ## Exercise 4
# Show each order with the customer name and product name (3-table join).

# %%
# your answer here

# %% [markdown]
# ## Exercise 5
# Show each employee alongside their manager's name (self join).

# %%
# your answer here

# %% [markdown]
# ## Exercise 6
# Compute total revenue per product category (join + group by).

# %%
# your answer here
