# %% [markdown]
# # Module 5 — Interview Q&A: Subqueries & CTEs
# ### SQL Mastery — PJ's Academy

# %% [markdown]
# > **Optional Reading**
# > Interview questions for self-study — not required before the next module.
# > Return here when preparing for interviews.

# %% [markdown]
# ## 🟢 Junior
# ### Q1: What is — A **subquery** is a SELECT inside another query — scalar (a value), list (with `IN`), or table (in `FROM`).
#
# **Answer:**
# A **subquery** is a SELECT inside another query — scalar (a value), list (with `IN`), or table (in `FROM`). (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q2: How does — **Correlated** subqueries reference the outer row and run per-row (often replaceable by window functions).
#
# **Answer:**
# **Correlated** subqueries reference the outer row and run per-row (often replaceable by window functions). (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q3: When/why would you — `EXISTS` / `NOT EXISTS` test for the presence of rows — the safe way to do anti-joins.
#
# **Answer:**
# `EXISTS` / `NOT EXISTS` test for the presence of rows — the safe way to do anti-joins. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟢 Junior
# ### Q4: What is — Prefer `NOT EXISTS` over `NOT IN` when NULLs are possible.
#
# **Answer:**
# Prefer `NOT EXISTS` over `NOT IN` when NULLs are possible. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q5: How does — **CTEs (`WITH`)** name intermediate results for readability; chain several to build complex logic in layers.
#
# **Answer:**
# **CTEs (`WITH`)** name intermediate results for readability; chain several to build complex logic in layers. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q6: When/why would you — Solve hard queries **one layer at a time**.
#
# **Answer:**
# Solve hard queries **one layer at a time**. (see the Tutorial for the full explanation and code example).
