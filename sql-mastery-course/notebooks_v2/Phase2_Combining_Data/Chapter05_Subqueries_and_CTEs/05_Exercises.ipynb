# %% [markdown]
# # Module 5 — Exercises: Subqueries & CTEs
# ### SQL Mastery — PJ's Academy
#
# Try each before checking the Tutorial.
#
# ---

# %% [markdown]
# ## Exercise 1
# Find employees earning more than the company average (scalar subquery).

# %%
# your answer here

# %% [markdown]
# ## Exercise 2
# Find employees in departments located in 'Bangalore' (list subquery with `IN`).

# %%
# your answer here

# %% [markdown]
# ## Exercise 3
# Find employees earning above their own department's average (correlated subquery).

# %%
# your answer here

# %% [markdown]
# ## Exercise 4
# Find customers who have never ordered, using `NOT EXISTS`.

# %%
# your answer here

# %% [markdown]
# ## Exercise 5
# Rewrite exercise 3 using a CTE that computes department averages.

# %%
# your answer here

# %% [markdown]
# ## Exercise 6
# Using two chained CTEs, list customers who spent above the average customer spend.

# %%
# your answer here
