# %% [markdown]
# # Module 5 Quiz — Subqueries & CTEs
# ### SQL Mastery — PJ's Academy
#
# Read each key concept, then confirm you can restate it. Reveal cells check yourself.
#
# ---

# %% [markdown]
# ### Q1. True or False — can you explain this in your own words?
#
# > A **subquery** is a SELECT inside another query — scalar (a value), list (with `IN`), or table (in `FROM`).

# %%
print('Self-check: re-read the Tutorial section covering — A **subquery** is a SELECT inside another query — scalar (a ...')

# %% [markdown]
# ### Q2. True or False — can you explain this in your own words?
#
# > **Correlated** subqueries reference the outer row and run per-row (often replaceable by window functions).

# %%
print('Self-check: re-read the Tutorial section covering — **Correlated** subqueries reference the outer row and run pe...')

# %% [markdown]
# ### Q3. True or False — can you explain this in your own words?
#
# > `EXISTS` / `NOT EXISTS` test for the presence of rows — the safe way to do anti-joins.

# %%
print('Self-check: re-read the Tutorial section covering — `EXISTS` / `NOT EXISTS` test for the presence of rows — the ...')

# %% [markdown]
# ### Q4. True or False — can you explain this in your own words?
#
# > Prefer `NOT EXISTS` over `NOT IN` when NULLs are possible.

# %%
print('Self-check: re-read the Tutorial section covering — Prefer `NOT EXISTS` over `NOT IN` when NULLs are possible....')

# %% [markdown]
# ### Q5. True or False — can you explain this in your own words?
#
# > **CTEs (`WITH`)** name intermediate results for readability; chain several to build complex logic in layers.

# %%
print('Self-check: re-read the Tutorial section covering — **CTEs (`WITH`)** name intermediate results for readability;...')

# %% [markdown]
# ### Q6. True or False — can you explain this in your own words?
#
# > Solve hard queries **one layer at a time**.

# %%
print('Self-check: re-read the Tutorial section covering — Solve hard queries **one layer at a time**....')
