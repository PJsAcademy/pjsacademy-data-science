# %% [markdown]
# # Module 1 — Exercises: Databases & SELECT Basics
# ### SQL Mastery — PJ's Academy
#
# Try each before checking the Tutorial.
#
# ---

# %% [markdown]
# ## Exercise 1
# Select all columns from `products`.

# %%
# your answer here

# %% [markdown]
# ## Exercise 2
# Select just `name` and `salary` from `employees`, salary first.

# %%
# your answer here

# %% [markdown]
# ## Exercise 3
# Show each product's `name` and its price × 1.18 (with GST) as `price_with_gst`.

# %%
# your answer here

# %% [markdown]
# ## Exercise 4
# List the distinct `city` values from `customers`.

# %%
# your answer here

# %% [markdown]
# ## Exercise 5
# Show the first 3 rows of `orders`.

# %%
# your answer here
