# %% [markdown]
# # Module 1 Quiz — Databases & SELECT Basics
# ### SQL Mastery — PJ's Academy
#
# Read each key concept, then confirm you can restate it. Reveal cells check yourself.
#
# ---

# %% [markdown]
# ### Q1. True or False — can you explain this in your own words?
#
# > A relational database stores data in **tables** (rows × columns), each column has a type.

# %%
print('Self-check: re-read the Tutorial section covering — A relational database stores data in **tables** (rows × colu...')

# %% [markdown]
# ### Q2. True or False — can you explain this in your own words?
#
# > `SELECT columns FROM table` retrieves data; `*` means all columns.

# %%
print('Self-check: re-read the Tutorial section covering — `SELECT columns FROM table` retrieves data; `*` means all co...')

# %% [markdown]
# ### Q3. True or False — can you explain this in your own words?
#
# > Use `AS` to **alias** (rename) output columns.

# %%
print('Self-check: re-read the Tutorial section covering — Use `AS` to **alias** (rename) output columns....')

# %% [markdown]
# ### Q4. True or False — can you explain this in your own words?
#
# > You can compute **calculated columns** (`salary * 12`) and concatenate text (`||`).

# %%
print('Self-check: re-read the Tutorial section covering — You can compute **calculated columns** (`salary * 12`) and c...')

# %% [markdown]
# ### Q5. True or False — can you explain this in your own words?
#
# > `DISTINCT` removes duplicates; `LIMIT` caps the number of rows.

# %%
print('Self-check: re-read the Tutorial section covering — `DISTINCT` removes duplicates; `LIMIT` caps the number of ro...')

# %% [markdown]
# ### Q6. True or False — can you explain this in your own words?
#
# > The database runs `FROM` before `SELECT`.

# %%
print('Self-check: re-read the Tutorial section covering — The database runs `FROM` before `SELECT`....')
