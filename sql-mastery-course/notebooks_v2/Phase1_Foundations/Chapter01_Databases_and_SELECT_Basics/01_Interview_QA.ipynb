# %% [markdown]
# # Module 1 — Interview Q&A: Databases & SELECT Basics
# ### SQL Mastery — PJ's Academy

# %% [markdown]
# > **Optional Reading**
# > Interview questions for self-study — not required before the next module.
# > Return here when preparing for interviews.

# %% [markdown]
# ## 🟢 Junior
# ### Q1: What is — A relational database stores data in **tables** (rows × columns), each column has a type.
#
# **Answer:**
# A relational database stores data in **tables** (rows × columns), each column has a type. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q2: How does — `SELECT columns FROM table` retrieves data; `*` means all columns.
#
# **Answer:**
# `SELECT columns FROM table` retrieves data; `*` means all columns. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q3: When/why would you — Use `AS` to **alias** (rename) output columns.
#
# **Answer:**
# Use `AS` to **alias** (rename) output columns. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟢 Junior
# ### Q4: What is — You can compute **calculated columns** (`salary * 12`) and concatenate text (`||`).
#
# **Answer:**
# You can compute **calculated columns** (`salary * 12`) and concatenate text (`||`). (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q5: How does — `DISTINCT` removes duplicates; `LIMIT` caps the number of rows.
#
# **Answer:**
# `DISTINCT` removes duplicates; `LIMIT` caps the number of rows. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q6: When/why would you — The database runs `FROM` before `SELECT`.
#
# **Answer:**
# The database runs `FROM` before `SELECT`. (see the Tutorial for the full explanation and code example).
