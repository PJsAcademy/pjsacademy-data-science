# %% [markdown]
# # Module 2 — Interview Q&A: Filtering, Sorting & Operators
# ### SQL Mastery — PJ's Academy

# %% [markdown]
# > **Optional Reading**
# > Interview questions for self-study — not required before the next module.
# > Return here when preparing for interviews.

# %% [markdown]
# ## 🟢 Junior
# ### Q1: What is — `WHERE` filters rows using comparison operators (`=`, `<>`, `>`, …).
#
# **Answer:**
# `WHERE` filters rows using comparison operators (`=`, `<>`, `>`, …). (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q2: How does — Combine conditions with `AND`/`OR`/`NOT`; use parentheses to control precedence.
#
# **Answer:**
# Combine conditions with `AND`/`OR`/`NOT`; use parentheses to control precedence. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q3: When/why would you — `BETWEEN` (ranges), `IN` (lists), `LIKE` (patterns with `%` and `_`).
#
# **Answer:**
# `BETWEEN` (ranges), `IN` (lists), `LIKE` (patterns with `%` and `_`). (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟢 Junior
# ### Q4: What is — `NULL` is unknown — use `IS NULL` / `IS NOT NULL`, never `= NULL`.
#
# **Answer:**
# `NULL` is unknown — use `IS NULL` / `IS NOT NULL`, never `= NULL`. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q5: How does — `ORDER BY col DESC/ASC` sorts; add columns for tie-breakers.
#
# **Answer:**
# `ORDER BY col DESC/ASC` sorts; add columns for tie-breakers. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q6: When/why would you — Sort + `LIMIT` = the top-N pattern. Remember the FROM→WHERE→SELECT→ORDER BY→LIMIT order.
#
# **Answer:**
# Sort + `LIMIT` = the top-N pattern. Remember the FROM→WHERE→SELECT→ORDER BY→LIMIT order. (see the Tutorial for the full explanation and code example).
