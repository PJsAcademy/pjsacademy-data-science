# %% [markdown]
# # Module 2 Quiz — Filtering, Sorting & Operators
# ### SQL Mastery — PJ's Academy
#
# Read each key concept, then confirm you can restate it. Reveal cells check yourself.
#
# ---

# %% [markdown]
# ### Q1. True or False — can you explain this in your own words?
#
# > `WHERE` filters rows using comparison operators (`=`, `<>`, `>`, …).

# %%
print('Self-check: re-read the Tutorial section covering — `WHERE` filters rows using comparison operators (`=`, `<>`, ...')

# %% [markdown]
# ### Q2. True or False — can you explain this in your own words?
#
# > Combine conditions with `AND`/`OR`/`NOT`; use parentheses to control precedence.

# %%
print('Self-check: re-read the Tutorial section covering — Combine conditions with `AND`/`OR`/`NOT`; use parentheses to...')

# %% [markdown]
# ### Q3. True or False — can you explain this in your own words?
#
# > `BETWEEN` (ranges), `IN` (lists), `LIKE` (patterns with `%` and `_`).

# %%
print('Self-check: re-read the Tutorial section covering — `BETWEEN` (ranges), `IN` (lists), `LIKE` (patterns with `%` ...')

# %% [markdown]
# ### Q4. True or False — can you explain this in your own words?
#
# > `NULL` is unknown — use `IS NULL` / `IS NOT NULL`, never `= NULL`.

# %%
print('Self-check: re-read the Tutorial section covering — `NULL` is unknown — use `IS NULL` / `IS NOT NULL`, never `= ...')

# %% [markdown]
# ### Q5. True or False — can you explain this in your own words?
#
# > `ORDER BY col DESC/ASC` sorts; add columns for tie-breakers.

# %%
print('Self-check: re-read the Tutorial section covering — `ORDER BY col DESC/ASC` sorts; add columns for tie-breakers....')

# %% [markdown]
# ### Q6. True or False — can you explain this in your own words?
#
# > Sort + `LIMIT` = the top-N pattern. Remember the FROM→WHERE→SELECT→ORDER BY→LIMIT order.

# %%
print('Self-check: re-read the Tutorial section covering — Sort + `LIMIT` = the top-N pattern. Remember the FROM→WHERE→...')
