# %% [markdown]
# # Module 2 — Exercises: Filtering, Sorting & Operators
# ### SQL Mastery — PJ's Academy
#
# Try each before checking the Tutorial.
#
# ---

# %% [markdown]
# ## Exercise 1
# List employees earning more than 90,000, highest salary first.

# %%
# your answer here

# %% [markdown]
# ## Exercise 2
# Find employees in departments 1 or 4 (use `IN`).

# %%
# your answer here

# %% [markdown]
# ## Exercise 3
# Find employees whose name contains the letter "a".

# %%
# your answer here

# %% [markdown]
# ## Exercise 4
# Find employees with no email (`IS NULL`).

# %%
# your answer here

# %% [markdown]
# ## Exercise 5
# Show the 2 cheapest products.

# %%
# your answer here

# %% [markdown]
# ## Exercise 6
# List employees hired between '2021-01-01' and '2021-12-31' (use `BETWEEN`).

# %%
# your answer here
