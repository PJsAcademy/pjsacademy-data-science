# %% [markdown]
# # Module 3 — Interview Q&A: Aggregations & GROUP BY
# ### SQL Mastery — PJ's Academy

# %% [markdown]
# > **Optional Reading**
# > Interview questions for self-study — not required before the next module.
# > Return here when preparing for interviews.

# %% [markdown]
# ## 🟢 Junior
# ### Q1: What is — Aggregates (`COUNT`, `SUM`, `AVG`, `MIN`, `MAX`) collapse many rows into one value.
#
# **Answer:**
# Aggregates (`COUNT`, `SUM`, `AVG`, `MIN`, `MAX`) collapse many rows into one value. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q2: How does — `COUNT(*)` counts rows; `COUNT(col)` ignores NULLs.
#
# **Answer:**
# `COUNT(*)` counts rows; `COUNT(col)` ignores NULLs. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q3: When/why would you — `GROUP BY X` gives one row per group — use it whenever you want results "per X".
#
# **Answer:**
# `GROUP BY X` gives one row per group — use it whenever you want results "per X". (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟢 Junior
# ### Q4: What is — Every selected column must be grouped or aggregated.
#
# **Answer:**
# Every selected column must be grouped or aggregated. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q5: How does — `WHERE` filters rows (before grouping); `HAVING` filters groups (after).
#
# **Answer:**
# `WHERE` filters rows (before grouping); `HAVING` filters groups (after). (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q6: When/why would you — `SUM(CASE WHEN … THEN 1 ELSE 0 END)` = conditional counting within groups.
#
# **Answer:**
# `SUM(CASE WHEN … THEN 1 ELSE 0 END)` = conditional counting within groups. (see the Tutorial for the full explanation and code example).
