# %% [markdown]
# # Module 3 — Exercises: Aggregations & GROUP BY
# ### SQL Mastery — PJ's Academy
#
# Try each before checking the Tutorial.
#
# ---

# %% [markdown]
# ## Exercise 1
# Count how many employees there are, and how many have an email.

# %%
# your answer here

# %% [markdown]
# ## Exercise 2
# Show the average salary per department.

# %%
# your answer here

# %% [markdown]
# ## Exercise 3
# Show total revenue per product category (join needed — or use `orders` alone by product_id).

# %%
# your answer here

# %% [markdown]
# ## Exercise 4
# List departments with an average salary above 90,000 (`HAVING`).

# %%
# your answer here

# %% [markdown]
# ## Exercise 5
# Count, per department, how many employees earn 100,000+ (conditional aggregation).

# %%
# your answer here

# %% [markdown]
# ## Exercise 6
# Show total order amount per customer, only for customers who spent over 20,000.

# %%
# your answer here
