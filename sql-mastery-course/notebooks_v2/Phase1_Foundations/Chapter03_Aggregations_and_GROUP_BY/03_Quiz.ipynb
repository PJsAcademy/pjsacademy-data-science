# %% [markdown]
# # Module 3 Quiz — Aggregations & GROUP BY
# ### SQL Mastery — PJ's Academy
#
# Read each key concept, then confirm you can restate it. Reveal cells check yourself.
#
# ---

# %% [markdown]
# ### Q1. True or False — can you explain this in your own words?
#
# > Aggregates (`COUNT`, `SUM`, `AVG`, `MIN`, `MAX`) collapse many rows into one value.

# %%
print('Self-check: re-read the Tutorial section covering — Aggregates (`COUNT`, `SUM`, `AVG`, `MIN`, `MAX`) collapse ma...')

# %% [markdown]
# ### Q2. True or False — can you explain this in your own words?
#
# > `COUNT(*)` counts rows; `COUNT(col)` ignores NULLs.

# %%
print('Self-check: re-read the Tutorial section covering — `COUNT(*)` counts rows; `COUNT(col)` ignores NULLs....')

# %% [markdown]
# ### Q3. True or False — can you explain this in your own words?
#
# > `GROUP BY X` gives one row per group — use it whenever you want results "per X".

# %%
print('Self-check: re-read the Tutorial section covering — `GROUP BY X` gives one row per group — use it whenever you w...')

# %% [markdown]
# ### Q4. True or False — can you explain this in your own words?
#
# > Every selected column must be grouped or aggregated.

# %%
print('Self-check: re-read the Tutorial section covering — Every selected column must be grouped or aggregated....')

# %% [markdown]
# ### Q5. True or False — can you explain this in your own words?
#
# > `WHERE` filters rows (before grouping); `HAVING` filters groups (after).

# %%
print('Self-check: re-read the Tutorial section covering — `WHERE` filters rows (before grouping); `HAVING` filters gro...')

# %% [markdown]
# ### Q6. True or False — can you explain this in your own words?
#
# > `SUM(CASE WHEN … THEN 1 ELSE 0 END)` = conditional counting within groups.

# %%
print('Self-check: re-read the Tutorial section covering — `SUM(CASE WHEN … THEN 1 ELSE 0 END)` = conditional counting ...')
