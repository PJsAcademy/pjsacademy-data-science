# %% [markdown]
# # Module 6 — Exercises: Window Functions
# ### SQL Mastery — PJ's Academy
#
# Try each before checking the Tutorial.
#
# ---

# %% [markdown]
# ## Exercise 1
# Rank all employees by salary using `RANK` and `DENSE_RANK`; note the difference on ties.

# %%
# your answer here

# %% [markdown]
# ## Exercise 2
# Rank employees by salary **within each department**.

# %%
# your answer here

# %% [markdown]
# ## Exercise 3
# Return the top 2 earners per department.

# %%
# your answer here

# %% [markdown]
# ## Exercise 4
# Show each employee's salary next to their department average and the difference.

# %%
# your answer here

# %% [markdown]
# ## Exercise 5
# Compute a running total of `orders.amount` ordered by date.

# %%
# your answer here

# %% [markdown]
# ## Exercise 6
# Show month-over-month revenue change using `LAG`.

# %%
# your answer here
