# %% [markdown]
# # Module 6 — Interview Q&A: Window Functions
# ### SQL Mastery — PJ's Academy

# %% [markdown]
# > **Optional Reading**
# > Interview questions for self-study — not required before the next module.
# > Return here when preparing for interviews.

# %% [markdown]
# ## 🟢 Junior
# ### Q1: What is — Window functions compute across related rows **without collapsing** them: `FUNC() OVER (PARTITION BY … ORDER BY …)`.
#
# **Answer:**
# Window functions compute across related rows **without collapsing** them: `FUNC() OVER (PARTITION BY … ORDER BY …)`. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q2: How does — `ROW_NUMBER` (unique), `RANK` (gaps), `DENSE_RANK` (no gaps) for ranking.
#
# **Answer:**
# `ROW_NUMBER` (unique), `RANK` (gaps), `DENSE_RANK` (no gaps) for ranking. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q3: When/why would you — `PARTITION BY` restarts the calculation per group — the key to per-group analytics.
#
# **Answer:**
# `PARTITION BY` restarts the calculation per group — the key to per-group analytics. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟢 Junior
# ### Q4: What is — **Top-N-per-group** = rank in a subquery/CTE, filter the rank (or Snowflake `QUALIFY`).
#
# **Answer:**
# **Top-N-per-group** = rank in a subquery/CTE, filter the rank (or Snowflake `QUALIFY`). (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q5: How does — Aggregate windows compare each row to its group average/total; add `ORDER BY` for running totals.
#
# **Answer:**
# Aggregate windows compare each row to its group average/total; add `ORDER BY` for running totals. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q6: When/why would you — `LAG`/`LEAD` compare to previous/next rows (period-over-period).
#
# **Answer:**
# `LAG`/`LEAD` compare to previous/next rows (period-over-period). (see the Tutorial for the full explanation and code example).
