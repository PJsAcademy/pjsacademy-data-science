# %% [markdown]
# # Module 6 Quiz — Window Functions
# ### SQL Mastery — PJ's Academy
#
# Read each key concept, then confirm you can restate it. Reveal cells check yourself.
#
# ---

# %% [markdown]
# ### Q1. True or False — can you explain this in your own words?
#
# > Window functions compute across related rows **without collapsing** them: `FUNC() OVER (PARTITION BY … ORDER BY …)`.

# %%
print('Self-check: re-read the Tutorial section covering — Window functions compute across related rows **without colla...')

# %% [markdown]
# ### Q2. True or False — can you explain this in your own words?
#
# > `ROW_NUMBER` (unique), `RANK` (gaps), `DENSE_RANK` (no gaps) for ranking.

# %%
print('Self-check: re-read the Tutorial section covering — `ROW_NUMBER` (unique), `RANK` (gaps), `DENSE_RANK` (no gaps)...')

# %% [markdown]
# ### Q3. True or False — can you explain this in your own words?
#
# > `PARTITION BY` restarts the calculation per group — the key to per-group analytics.

# %%
print('Self-check: re-read the Tutorial section covering — `PARTITION BY` restarts the calculation per group — the key ...')

# %% [markdown]
# ### Q4. True or False — can you explain this in your own words?
#
# > **Top-N-per-group** = rank in a subquery/CTE, filter the rank (or Snowflake `QUALIFY`).

# %%
print('Self-check: re-read the Tutorial section covering — **Top-N-per-group** = rank in a subquery/CTE, filter the ran...')

# %% [markdown]
# ### Q5. True or False — can you explain this in your own words?
#
# > Aggregate windows compare each row to its group average/total; add `ORDER BY` for running totals.

# %%
print('Self-check: re-read the Tutorial section covering — Aggregate windows compare each row to its group average/tota...')

# %% [markdown]
# ### Q6. True or False — can you explain this in your own words?
#
# > `LAG`/`LEAD` compare to previous/next rows (period-over-period).

# %%
print('Self-check: re-read the Tutorial section covering — `LAG`/`LEAD` compare to previous/next rows (period-over-peri...')
