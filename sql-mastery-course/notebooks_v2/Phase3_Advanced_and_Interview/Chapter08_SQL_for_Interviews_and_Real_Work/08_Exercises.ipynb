# %% [markdown]
# # Module 8 — Exercises: SQL for Interviews & Real Work
# ### SQL Mastery — PJ's Academy
#
# Try each before checking the Tutorial.
#
# ---

# %% [markdown]
# ## Exercise 1
# Write the second-highest salary query, then generalise it to Nth-highest.

# %%
# your answer here

# %% [markdown]
# ## Exercise 2
# Find all duplicate emails in `employees`.

# %%
# your answer here

# %% [markdown]
# ## Exercise 3
# Find employees earning more than their manager.

# %%
# your answer here

# %% [markdown]
# ## Exercise 4
# List customers who never ordered (two ways: `LEFT JOIN` and `NOT EXISTS`).

# %%
# your answer here

# %% [markdown]
# ## Exercise 5
# For each department, return the top earner (window function).

# %%
# your answer here

# %% [markdown]
# ## Exercise 6
# Pick 5 problems from the Hard bank and solve them timed.

# %%
# your answer here
