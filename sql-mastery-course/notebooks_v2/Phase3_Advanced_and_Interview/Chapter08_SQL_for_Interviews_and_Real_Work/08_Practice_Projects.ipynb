# %% [markdown]
# # Module 8 — Practice Project: SQL for Interviews & Real Work
# ### SQL Mastery — PJ's Academy
#
# ---

# %% [markdown]
# _See the course-level `projects.md` for the full project list tied to this module._
