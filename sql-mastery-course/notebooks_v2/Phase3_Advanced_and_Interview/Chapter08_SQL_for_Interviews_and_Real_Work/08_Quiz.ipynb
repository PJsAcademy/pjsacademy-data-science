# %% [markdown]
# # Module 8 Quiz — SQL for Interviews & Real Work
# ### SQL Mastery — PJ's Academy
#
# Read each key concept, then confirm you can restate it. Reveal cells check yourself.
#
# ---

# %% [markdown]
# ### Q1. True or False — can you explain this in your own words?
#
# > Attack problems with a **method**: restate → identify tables/grain → build in layers → test → sanity-check.

# %%
print('Self-check: re-read the Tutorial section covering — Attack problems with a **method**: restate → identify tables...')

# %% [markdown]
# ### Q2. True or False — can you explain this in your own words?
#
# > Learn the **9 core patterns** — they cover ~90% of interviews.

# %%
print('Self-check: re-read the Tutorial section covering — Learn the **9 core patterns** — they cover ~90% of interview...')

# %% [markdown]
# ### Q3. True or False — can you explain this in your own words?
#
# > Know the **classic questions** (2nd-highest, duplicates, more-than-manager, never-ordered) cold.

# %%
print('Self-check: re-read the Tutorial section covering — Know the **classic questions** (2nd-highest, duplicates, mor...')

# %% [markdown]
# ### Q4. True or False — can you explain this in your own words?
#
# > Write **readable** SQL (CTEs, aliases, formatting) — it's judged.

# %%
print('Self-check: re-read the Tutorial section covering — Write **readable** SQL (CTEs, aliases, formatting) — it's ju...')

# %% [markdown]
# ### Q5. True or False — can you explain this in your own words?
#
# > Build **correctness habits**: dedupe after joins, `NOT EXISTS` for NULLs, decimal math, `NULLIF` guards.

# %%
print('Self-check: re-read the Tutorial section covering — Build **correctness habits**: dedupe after joins, `NOT EXIST...')

# %% [markdown]
# ### Q6. True or False — can you explain this in your own words?
#
# > Core SQL is portable; know your engine's dialect and performance model.

# %%
print('Self-check: re-read the Tutorial section covering — Core SQL is portable; know your engine's dialect and perform...')
