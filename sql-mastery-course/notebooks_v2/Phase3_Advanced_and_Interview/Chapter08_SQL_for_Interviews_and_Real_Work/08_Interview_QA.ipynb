# %% [markdown]
# # Module 8 — Interview Q&A: SQL for Interviews & Real Work
# ### SQL Mastery — PJ's Academy

# %% [markdown]
# > **Optional Reading**
# > Interview questions for self-study — not required before the next module.
# > Return here when preparing for interviews.

# %% [markdown]
# ## 🟢 Junior
# ### Q1: What is — Attack problems with a **method**: restate → identify tables/grain → build in layers → test → sanity-check.
#
# **Answer:**
# Attack problems with a **method**: restate → identify tables/grain → build in layers → test → sanity-check. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q2: How does — Learn the **9 core patterns** — they cover ~90% of interviews.
#
# **Answer:**
# Learn the **9 core patterns** — they cover ~90% of interviews. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q3: When/why would you — Know the **classic questions** (2nd-highest, duplicates, more-than-manager, never-ordered) cold.
#
# **Answer:**
# Know the **classic questions** (2nd-highest, duplicates, more-than-manager, never-ordered) cold. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟢 Junior
# ### Q4: What is — Write **readable** SQL (CTEs, aliases, formatting) — it's judged.
#
# **Answer:**
# Write **readable** SQL (CTEs, aliases, formatting) — it's judged. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q5: How does — Build **correctness habits**: dedupe after joins, `NOT EXISTS` for NULLs, decimal math, `NULLIF` guards.
#
# **Answer:**
# Build **correctness habits**: dedupe after joins, `NOT EXISTS` for NULLs, decimal math, `NULLIF` guards. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q6: When/why would you — Core SQL is portable; know your engine's dialect and performance model.
#
# **Answer:**
# Core SQL is portable; know your engine's dialect and performance model. (see the Tutorial for the full explanation and code example).
