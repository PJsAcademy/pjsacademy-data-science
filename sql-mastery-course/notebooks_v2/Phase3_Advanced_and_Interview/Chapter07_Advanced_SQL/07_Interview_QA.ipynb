# %% [markdown]
# # Module 7 — Interview Q&A: Advanced SQL
# ### SQL Mastery — PJ's Academy

# %% [markdown]
# > **Optional Reading**
# > Interview questions for self-study — not required before the next module.
# > Return here when preparing for interviews.

# %% [markdown]
# ## 🟢 Junior
# ### Q1: What is — `CASE` = conditional logic; powers labels, bucketing, and pivots (rows→columns).
#
# **Answer:**
# `CASE` = conditional logic; powers labels, bucketing, and pivots (rows→columns). (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q2: How does — Set ops: `UNION`(/ALL), `INTERSECT`, `EXCEPT` stack/compare result sets.
#
# **Answer:**
# Set ops: `UNION`(/ALL), `INTERSECT`, `EXCEPT` stack/compare result sets. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q3: When/why would you — `ROLLUP`/`CUBE`/`GROUPING SETS` add subtotals and grand totals.
#
# **Answer:**
# `ROLLUP`/`CUBE`/`GROUPING SETS` add subtotals and grand totals. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟢 Junior
# ### Q4: What is — Master **date functions** (`DATE_TRUNC`, `DATEDIFF`) and **string functions** (`SPLIT_PART`, `LISTAGG`).
#
# **Answer:**
# Master **date functions** (`DATE_TRUNC`, `DATEDIFF`) and **string functions** (`SPLIT_PART`, `LISTAGG`). (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q5: How does — **Recursive CTEs** handle hierarchies and generated series (anchor + recursive step).
#
# **Answer:**
# **Recursive CTEs** handle hierarchies and generated series (anchor + recursive step). (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q6: When/why would you — `COALESCE`/`NULLIF` handle NULLs and guard divide-by-zero; filter early and avoid functions on filtered columns for speed.
#
# **Answer:**
# `COALESCE`/`NULLIF` handle NULLs and guard divide-by-zero; filter early and avoid functions on filtered columns for speed. (see the Tutorial for the full explanation and code example).
