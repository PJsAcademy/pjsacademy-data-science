# %% [markdown]
# # Module 7 Quiz — Advanced SQL
# ### SQL Mastery — PJ's Academy
#
# Read each key concept, then confirm you can restate it. Reveal cells check yourself.
#
# ---

# %% [markdown]
# ### Q1. True or False — can you explain this in your own words?
#
# > `CASE` = conditional logic; powers labels, bucketing, and pivots (rows→columns).

# %%
print('Self-check: re-read the Tutorial section covering — `CASE` = conditional logic; powers labels, bucketing, and pi...')

# %% [markdown]
# ### Q2. True or False — can you explain this in your own words?
#
# > Set ops: `UNION`(/ALL), `INTERSECT`, `EXCEPT` stack/compare result sets.

# %%
print('Self-check: re-read the Tutorial section covering — Set ops: `UNION`(/ALL), `INTERSECT`, `EXCEPT` stack/compare ...')

# %% [markdown]
# ### Q3. True or False — can you explain this in your own words?
#
# > `ROLLUP`/`CUBE`/`GROUPING SETS` add subtotals and grand totals.

# %%
print('Self-check: re-read the Tutorial section covering — `ROLLUP`/`CUBE`/`GROUPING SETS` add subtotals and grand tota...')

# %% [markdown]
# ### Q4. True or False — can you explain this in your own words?
#
# > Master **date functions** (`DATE_TRUNC`, `DATEDIFF`) and **string functions** (`SPLIT_PART`, `LISTAGG`).

# %%
print('Self-check: re-read the Tutorial section covering — Master **date functions** (`DATE_TRUNC`, `DATEDIFF`) and **s...')

# %% [markdown]
# ### Q5. True or False — can you explain this in your own words?
#
# > **Recursive CTEs** handle hierarchies and generated series (anchor + recursive step).

# %%
print('Self-check: re-read the Tutorial section covering — **Recursive CTEs** handle hierarchies and generated series (...')

# %% [markdown]
# ### Q6. True or False — can you explain this in your own words?
#
# > `COALESCE`/`NULLIF` handle NULLs and guard divide-by-zero; filter early and avoid functions on filtered columns for speed.

# %%
print('Self-check: re-read the Tutorial section covering — `COALESCE`/`NULLIF` handle NULLs and guard divide-by-zero; f...')
