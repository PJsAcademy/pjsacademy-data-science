# %% [markdown]
# # Module 7 — Exercises: Advanced SQL
# ### SQL Mastery — PJ's Academy
#
# Try each before checking the Tutorial.
#
# ---

# %% [markdown]
# ## Exercise 1
# Label each employee's salary as High/Medium/Low with `CASE`.

# %%
# your answer here

# %% [markdown]
# ## Exercise 2
# Pivot: show total revenue for Electronics vs Furniture as two columns.

# %%
# your answer here

# %% [markdown]
# ## Exercise 3
# Use `UNION` to list all employee and customer names in one column.

# %%
# your answer here

# %% [markdown]
# ## Exercise 4
# Use `ROLLUP` to show headcount per department plus a grand total.

# %%
# your answer here

# %% [markdown]
# ## Exercise 5
# Extract the email domain of each employee (`SPLIT_PART` or `SUBSTRING`).

# %%
# your answer here

# %% [markdown]
# ## Exercise 6
# Write a recursive CTE that lists numbers 1 to 10.

# %%
# your answer here
