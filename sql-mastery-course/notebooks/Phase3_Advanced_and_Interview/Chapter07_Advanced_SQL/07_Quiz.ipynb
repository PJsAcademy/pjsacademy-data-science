# %% [markdown]
# # Chapter 07 — Quiz: Advanced SQL
# ### PJ's Academy · SQL Mastery
#
# Answer from memory, then re-read the tutorial to check.
#
# ---

# %% [markdown]
# **Q1.** Explain in your own words: `CASE` = conditional logic; powers labels, bucketing, and pivots (rows→columns).

# %% [markdown]
# **Q2.** Explain in your own words: Set ops: `UNION`(/ALL), `INTERSECT`, `EXCEPT` stack/compare result sets.

# %% [markdown]
# **Q3.** Explain in your own words: `ROLLUP`/`CUBE`/`GROUPING SETS` add subtotals and grand totals.

# %% [markdown]
# **Q4.** Explain in your own words: Master **date functions** (`DATE_TRUNC`, `DATEDIFF`) and **string functions** (`SPLIT_PART`, `LISTAGG`).

# %% [markdown]
# **Q5.** Explain in your own words: **Recursive CTEs** handle hierarchies and generated series (anchor + recursive step).

# %% [markdown]
# **Q6.** Explain in your own words: `COALESCE`/`NULLIF` handle NULLs and guard divide-by-zero; filter early and avoid functions on filtered columns for speed.

# %% [markdown]
# ---
# *Check your answers against the tutorial's Key Takeaways.*
