# %% [markdown]
# # Chapter 08 — Quiz: SQL for Interviews & Real Work
# ### PJ's Academy · SQL Mastery
#
# Answer from memory, then re-read the tutorial to check.
#
# ---

# %% [markdown]
# **Q1.** Explain in your own words: Attack problems with a **method**: restate → identify tables/grain → build in layers → test → sanity-check.

# %% [markdown]
# **Q2.** Explain in your own words: Learn the **9 core patterns** — they cover ~90% of interviews.

# %% [markdown]
# **Q3.** Explain in your own words: Know the **classic questions** (2nd-highest, duplicates, more-than-manager, never-ordered) cold.

# %% [markdown]
# **Q4.** Explain in your own words: Write **readable** SQL (CTEs, aliases, formatting) — it's judged.

# %% [markdown]
# **Q5.** Explain in your own words: Build **correctness habits**: dedupe after joins, `NOT EXISTS` for NULLs, decimal math, `NULLIF` guards.

# %% [markdown]
# **Q6.** Explain in your own words: Core SQL is portable; know your engine's dialect and performance model.

# %% [markdown]
# ---
# *Check your answers against the tutorial's Key Takeaways.*
