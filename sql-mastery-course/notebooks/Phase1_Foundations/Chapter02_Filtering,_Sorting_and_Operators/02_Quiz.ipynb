# %% [markdown]
# # Chapter 02 — Quiz: Filtering, Sorting & Operators
# ### PJ's Academy · SQL Mastery
#
# Answer from memory, then re-read the tutorial to check.
#
# ---

# %% [markdown]
# **Q1.** Explain in your own words: `WHERE` filters rows using comparison operators (`=`, `<>`, `>`, …).

# %% [markdown]
# **Q2.** Explain in your own words: Combine conditions with `AND`/`OR`/`NOT`; use parentheses to control precedence.

# %% [markdown]
# **Q3.** Explain in your own words: `BETWEEN` (ranges), `IN` (lists), `LIKE` (patterns with `%` and `_`).

# %% [markdown]
# **Q4.** Explain in your own words: `NULL` is unknown — use `IS NULL` / `IS NOT NULL`, never `= NULL`.

# %% [markdown]
# **Q5.** Explain in your own words: `ORDER BY col DESC/ASC` sorts; add columns for tie-breakers.

# %% [markdown]
# **Q6.** Explain in your own words: Sort + `LIMIT` = the top-N pattern. Remember the FROM→WHERE→SELECT→ORDER BY→LIMIT order.

# %% [markdown]
# ---
# *Check your answers against the tutorial's Key Takeaways.*
