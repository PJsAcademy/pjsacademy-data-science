# %% [markdown]
# # Chapter 01 — Quiz: Databases & SELECT Basics
# ### PJ's Academy · SQL Mastery
#
# Answer from memory, then re-read the tutorial to check.
#
# ---

# %% [markdown]
# **Q1.** Explain in your own words: A relational database stores data in **tables** (rows × columns), each column has a type.

# %% [markdown]
# **Q2.** Explain in your own words: `SELECT columns FROM table` retrieves data; `*` means all columns.

# %% [markdown]
# **Q3.** Explain in your own words: Use `AS` to **alias** (rename) output columns.

# %% [markdown]
# **Q4.** Explain in your own words: You can compute **calculated columns** (`salary * 12`) and concatenate text (`||`).

# %% [markdown]
# **Q5.** Explain in your own words: `DISTINCT` removes duplicates; `LIMIT` caps the number of rows.

# %% [markdown]
# **Q6.** Explain in your own words: The database runs `FROM` before `SELECT`.

# %% [markdown]
# ---
# *Check your answers against the tutorial's Key Takeaways.*
