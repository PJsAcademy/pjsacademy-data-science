# %% [markdown]
# # Chapter 03 — Quiz: Aggregations & GROUP BY
# ### PJ's Academy · SQL Mastery
#
# Answer from memory, then re-read the tutorial to check.
#
# ---

# %% [markdown]
# **Q1.** Explain in your own words: Aggregates (`COUNT`, `SUM`, `AVG`, `MIN`, `MAX`) collapse many rows into one value.

# %% [markdown]
# **Q2.** Explain in your own words: `COUNT(*)` counts rows; `COUNT(col)` ignores NULLs.

# %% [markdown]
# **Q3.** Explain in your own words: `GROUP BY X` gives one row per group — use it whenever you want results "per X".

# %% [markdown]
# **Q4.** Explain in your own words: Every selected column must be grouped or aggregated.

# %% [markdown]
# **Q5.** Explain in your own words: `WHERE` filters rows (before grouping); `HAVING` filters groups (after).

# %% [markdown]
# **Q6.** Explain in your own words: `SUM(CASE WHEN … THEN 1 ELSE 0 END)` = conditional counting within groups.

# %% [markdown]
# ---
# *Check your answers against the tutorial's Key Takeaways.*
