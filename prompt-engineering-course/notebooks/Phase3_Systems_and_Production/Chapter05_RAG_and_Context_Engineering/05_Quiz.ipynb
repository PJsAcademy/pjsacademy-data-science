# %% [markdown]
# # Chapter 05 — Quiz: RAG & Context Engineering
# ### PJ's Academy · Prompt Engineering Mastery
#
# Answer from memory, then re-read the tutorial to check.
#
# ---

# %% [markdown]
# **Q1.** Explain in your own words: **RAG** turns "recall from memory" (hard) into "read the provided text" (easy) — the anti-hallucination workhorse.

# %% [markdown]
# **Q2.** Explain in your own words: Pipeline: chunk → embed → store → retrieve → **ground in the prompt**.

# %% [markdown]
# **Q3.** Explain in your own words: The **grounding prompt** ("ONLY the context", abstain, cite) is where prompt engineering earns its keep.

# %% [markdown]
# **Q4.** Explain in your own words: **Chunking + retrieval quality** matter more than the model choice.

# %% [markdown]
# **Q5.** Explain in your own words: Use **hybrid search + re-ranking** for serious systems.

# %% [markdown]
# **Q6.** Explain in your own words: **Context engineering:** relevance over volume, important info at the edges.

# %% [markdown]
# ---
# *Check your answers against the tutorial's Key Takeaways.*
