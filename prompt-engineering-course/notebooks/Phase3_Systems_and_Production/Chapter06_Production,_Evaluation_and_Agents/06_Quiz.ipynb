# %% [markdown]
# # Chapter 06 — Quiz: Production, Evaluation & Agents
# ### PJ's Academy · Prompt Engineering Mastery
#
# Answer from memory, then re-read the tutorial to check.
#
# ---

# %% [markdown]
# **Q1.** Explain in your own words: **Evaluate** with an eval set on every change — measure, don't vibe.

# %% [markdown]
# **Q2.** Explain in your own words: **LLM-as-judge** scales quality scoring for open-ended output.

# %% [markdown]
# **Q3.** Explain in your own words: **Guardrails:** treat all user/tool/document content as untrusted *data*, not instructions.

# %% [markdown]
# **Q4.** Explain in your own words: **Optimise cost** by routing to the right-sized model, caching, and trimming.

# %% [markdown]
# **Q5.** Explain in your own words: **Chain** simple prompts instead of one mega-prompt.

# %% [markdown]
# **Q6.** Explain in your own words: An **agent** = LLM in a loop with tools; constrain steps, confirm risky actions, log traces.

# %% [markdown]
# ---
# *Check your answers against the tutorial's Key Takeaways.*
