# %% [markdown]
# # Chapter 01 — Quiz: Foundations: How LLMs Work
# ### PJ's Academy · Prompt Engineering Mastery
#
# Answer from memory, then re-read the tutorial to check.
#
# ---

# %% [markdown]
# **Q1.** Explain in your own words: An LLM predicts the next token — shape the input so the right answer is the most plausible continuation.

# %% [markdown]
# **Q2.** Explain in your own words: Everything is measured in **tokens** (cost, context, character-level weakness).

# %% [markdown]
# **Q3.** Explain in your own words: Each API call is **stateless**; "memory" is re-sent history.

# %% [markdown]
# **Q4.** Explain in your own words: **Temperature low** for facts/code, **high** for creativity.

# %% [markdown]
# **Q5.** Explain in your own words: The **system prompt** is your main control surface.

# %% [markdown]
# **Q6.** Explain in your own words: Hallucination comes from optimising plausibility — fix it with grounding, permission to abstain, and verification.

# %% [markdown]
# ---
# *Check your answers against the tutorial's Key Takeaways.*
