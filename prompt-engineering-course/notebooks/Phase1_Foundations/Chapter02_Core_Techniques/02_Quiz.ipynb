# %% [markdown]
# # Chapter 02 — Quiz: Core Techniques
# ### PJ's Academy · Prompt Engineering Mastery
#
# Answer from memory, then re-read the tutorial to check.
#
# ---

# %% [markdown]
# **Q1.** Explain in your own words: Structure prompts with Role · Task · Context · Input · Constraints · Format.

# %% [markdown]
# **Q2.** Explain in your own words: **Few-shot** examples are the most reliable lever — 2–5 diverse, identically-formatted.

# %% [markdown]
# **Q3.** Explain in your own words: **Delimiters** separate instructions from data (and block injection).

# %% [markdown]
# **Q4.** Explain in your own words: Be **specific and positive**; always give the model an "I don't know" out.

# %% [markdown]
# **Q5.** Explain in your own words: Prompt engineering is **iterative** — test on varied inputs, fix failures one at a time.

# %% [markdown]
# ---
# *Check your answers against the tutorial's Key Takeaways.*
