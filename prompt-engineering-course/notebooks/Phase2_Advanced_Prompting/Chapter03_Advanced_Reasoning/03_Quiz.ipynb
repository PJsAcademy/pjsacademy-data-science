# %% [markdown]
# # Chapter 03 — Quiz: Advanced Reasoning
# ### PJ's Academy · Prompt Engineering Mastery
#
# Answer from memory, then re-read the tutorial to check.
#
# ---

# %% [markdown]
# **Q1.** Explain in your own words: **Chain-of-thought** ("think step by step") boosts multi-step accuracy by making reasoning explicit.

# %% [markdown]
# **Q2.** Explain in your own words: **Self-consistency** = run CoT several times, take the majority answer.

# %% [markdown]
# **Q3.** Explain in your own words: **Decompose** hard tasks — one prompt, one job.

# %% [markdown]
# **Q4.** Explain in your own words: **ReAct** interleaves reasoning with tool calls — the foundation of agents.

# %% [markdown]
# **Q5.** Explain in your own words: **Self-critique** catches errors before the user sees them.

# %% [markdown]
# **Q6.** Explain in your own words: Don't over-apply — simple tasks don't need reasoning scaffolds.

# %% [markdown]
# ---
# *Check your answers against the tutorial's Key Takeaways.*
