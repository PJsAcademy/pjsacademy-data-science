# %% [markdown]
# # Module 5 — Exercises: RAG & Context Engineering
# ### Prompt Engineering Mastery — PJ's Academy
#
# Try each before checking the Tutorial.
#
# ---

# %% [markdown]
# ## Exercise 1
# Paste a document into an LLM with the grounding prompt from 5.3. Ask something not in it — confirm it abstains.

# %%
# your answer here

# %% [markdown]
# ## Exercise 2
# Chunk a long doc two ways (500 chars vs section-based). Compare which gives better answers.

# %%
# your answer here

# %% [markdown]
# ## Exercise 3
# Write a grounding prompt that forces `[source]` citations and test it.

# %%
# your answer here
