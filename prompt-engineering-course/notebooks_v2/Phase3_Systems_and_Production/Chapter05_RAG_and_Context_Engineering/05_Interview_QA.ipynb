# %% [markdown]
# # Module 5 — Interview Q&A: RAG & Context Engineering
# ### Prompt Engineering Mastery — PJ's Academy

# %% [markdown]
# > **Optional Reading**
# > Interview questions for self-study — not required before the next module.
# > Return here when preparing for interviews.

# %% [markdown]
# ## 🟢 Junior
# ### Q1: What is — **RAG** turns "recall from memory" (hard) into "read the provided text" (easy) — the anti-hallucination workhorse.
#
# **Answer:**
# **RAG** turns "recall from memory" (hard) into "read the provided text" (easy) — the anti-hallucination workhorse. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q2: How does — Pipeline: chunk → embed → store → retrieve → **ground in the prompt**.
#
# **Answer:**
# Pipeline: chunk → embed → store → retrieve → **ground in the prompt**. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q3: When/why would you — The **grounding prompt** ("ONLY the context", abstain, cite) is where prompt engineering earns its keep.
#
# **Answer:**
# The **grounding prompt** ("ONLY the context", abstain, cite) is where prompt engineering earns its keep. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟢 Junior
# ### Q4: What is — **Chunking + retrieval quality** matter more than the model choice.
#
# **Answer:**
# **Chunking + retrieval quality** matter more than the model choice. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q5: How does — Use **hybrid search + re-ranking** for serious systems.
#
# **Answer:**
# Use **hybrid search + re-ranking** for serious systems. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q6: When/why would you — **Context engineering:** relevance over volume, important info at the edges.
#
# **Answer:**
# **Context engineering:** relevance over volume, important info at the edges. (see the Tutorial for the full explanation and code example).
