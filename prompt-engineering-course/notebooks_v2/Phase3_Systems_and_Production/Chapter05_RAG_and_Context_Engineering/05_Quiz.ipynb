# %% [markdown]
# # Module 5 Quiz — RAG & Context Engineering
# ### Prompt Engineering Mastery — PJ's Academy
#
# Read each key concept, then confirm you can restate it. Reveal cells check yourself.
#
# ---

# %% [markdown]
# ### Q1. True or False — can you explain this in your own words?
#
# > **RAG** turns "recall from memory" (hard) into "read the provided text" (easy) — the anti-hallucination workhorse.

# %%
print('Self-check: re-read the Tutorial section covering — **RAG** turns "recall from memory" (hard) into "read the pro...')

# %% [markdown]
# ### Q2. True or False — can you explain this in your own words?
#
# > Pipeline: chunk → embed → store → retrieve → **ground in the prompt**.

# %%
print('Self-check: re-read the Tutorial section covering — Pipeline: chunk → embed → store → retrieve → **ground in the...')

# %% [markdown]
# ### Q3. True or False — can you explain this in your own words?
#
# > The **grounding prompt** ("ONLY the context", abstain, cite) is where prompt engineering earns its keep.

# %%
print('Self-check: re-read the Tutorial section covering — The **grounding prompt** ("ONLY the context", abstain, cite)...')

# %% [markdown]
# ### Q4. True or False — can you explain this in your own words?
#
# > **Chunking + retrieval quality** matter more than the model choice.

# %%
print('Self-check: re-read the Tutorial section covering — **Chunking + retrieval quality** matter more than the model ...')

# %% [markdown]
# ### Q5. True or False — can you explain this in your own words?
#
# > Use **hybrid search + re-ranking** for serious systems.

# %%
print('Self-check: re-read the Tutorial section covering — Use **hybrid search + re-ranking** for serious systems....')

# %% [markdown]
# ### Q6. True or False — can you explain this in your own words?
#
# > **Context engineering:** relevance over volume, important info at the edges.

# %%
print('Self-check: re-read the Tutorial section covering — **Context engineering:** relevance over volume, important in...')
