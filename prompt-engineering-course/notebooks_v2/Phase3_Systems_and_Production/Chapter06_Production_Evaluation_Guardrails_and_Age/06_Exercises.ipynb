# %% [markdown]
# # Module 6 — Exercises: Production, Evaluation, Guardrails & Agents
# ### Prompt Engineering Mastery — PJ's Academy
#
# Try each before checking the Tutorial.
#
# ---

# %% [markdown]
# ## Exercise 1
# Build a 10-row eval set for a prompt and score two prompt versions against it.

# %%
# your answer here

# %% [markdown]
# ## Exercise 2
# Write an LLM-as-judge prompt that scores answer faithfulness 1–5.

# %%
# your answer here

# %% [markdown]
# ## Exercise 3
# Attempt a prompt injection on your own prompt, then add a delimiter + "treat as data" defense and confirm it holds.

# %%
# your answer here

# %% [markdown]
# ## Exercise 4
# Sketch an agent for "research a company and write a one-page brief": list its tools, loop limit, and where you'd require human approval.

# %%
# your answer here
