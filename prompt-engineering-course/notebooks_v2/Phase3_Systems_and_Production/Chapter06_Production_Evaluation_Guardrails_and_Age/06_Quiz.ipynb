# %% [markdown]
# # Module 6 Quiz — Production, Evaluation, Guardrails & Agents
# ### Prompt Engineering Mastery — PJ's Academy
#
# Read each key concept, then confirm you can restate it. Reveal cells check yourself.
#
# ---

# %% [markdown]
# ### Q1. True or False — can you explain this in your own words?
#
# > **Evaluate** with an eval set on every change — measure, don't vibe.

# %%
print('Self-check: re-read the Tutorial section covering — **Evaluate** with an eval set on every change — measure, don...')

# %% [markdown]
# ### Q2. True or False — can you explain this in your own words?
#
# > **LLM-as-judge** scales quality scoring for open-ended output.

# %%
print('Self-check: re-read the Tutorial section covering — **LLM-as-judge** scales quality scoring for open-ended outpu...')

# %% [markdown]
# ### Q3. True or False — can you explain this in your own words?
#
# > **Guardrails:** treat all user/tool/document content as untrusted *data*, not instructions.

# %%
print('Self-check: re-read the Tutorial section covering — **Guardrails:** treat all user/tool/document content as untr...')

# %% [markdown]
# ### Q4. True or False — can you explain this in your own words?
#
# > **Optimise cost** by routing to the right-sized model, caching, and trimming.

# %%
print('Self-check: re-read the Tutorial section covering — **Optimise cost** by routing to the right-sized model, cachi...')

# %% [markdown]
# ### Q5. True or False — can you explain this in your own words?
#
# > **Chain** simple prompts instead of one mega-prompt.

# %%
print('Self-check: re-read the Tutorial section covering — **Chain** simple prompts instead of one mega-prompt....')

# %% [markdown]
# ### Q6. True or False — can you explain this in your own words?
#
# > An **agent** = LLM in a loop with tools; constrain steps, confirm risky actions, log traces.

# %%
print('Self-check: re-read the Tutorial section covering — An **agent** = LLM in a loop with tools; constrain steps, co...')
