# %% [markdown]
# # Module 6 — Practice Project: Production, Evaluation, Guardrails & Agents
# ### Prompt Engineering Mastery — PJ's Academy
#
# ---

# %% [markdown]
# _See the course-level `projects.md` for the full project list tied to this module._
