# %% [markdown]
# # Module 6 — Interview Q&A: Production, Evaluation, Guardrails & Agents
# ### Prompt Engineering Mastery — PJ's Academy

# %% [markdown]
# > **Optional Reading**
# > Interview questions for self-study — not required before the next module.
# > Return here when preparing for interviews.

# %% [markdown]
# ## 🟢 Junior
# ### Q1: What is — **Evaluate** with an eval set on every change — measure, don't vibe.
#
# **Answer:**
# **Evaluate** with an eval set on every change — measure, don't vibe. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q2: How does — **LLM-as-judge** scales quality scoring for open-ended output.
#
# **Answer:**
# **LLM-as-judge** scales quality scoring for open-ended output. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q3: When/why would you — **Guardrails:** treat all user/tool/document content as untrusted *data*, not instructions.
#
# **Answer:**
# **Guardrails:** treat all user/tool/document content as untrusted *data*, not instructions. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟢 Junior
# ### Q4: What is — **Optimise cost** by routing to the right-sized model, caching, and trimming.
#
# **Answer:**
# **Optimise cost** by routing to the right-sized model, caching, and trimming. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q5: How does — **Chain** simple prompts instead of one mega-prompt.
#
# **Answer:**
# **Chain** simple prompts instead of one mega-prompt. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q6: When/why would you — An **agent** = LLM in a loop with tools; constrain steps, confirm risky actions, log traces.
#
# **Answer:**
# An **agent** = LLM in a loop with tools; constrain steps, confirm risky actions, log traces. (see the Tutorial for the full explanation and code example).
