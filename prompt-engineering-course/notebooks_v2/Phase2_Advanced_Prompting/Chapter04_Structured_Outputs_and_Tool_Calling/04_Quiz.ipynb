# %% [markdown]
# # Module 4 Quiz — Structured Outputs & Tool Calling
# ### Prompt Engineering Mastery — PJ's Academy
#
# Read each key concept, then confirm you can restate it. Reveal cells check yourself.
#
# ---

# %% [markdown]
# ### Q1. True or False — can you explain this in your own words?
#
# > Applications need **machine-readable output** — reliability is the whole game.

# %%
print('Self-check: re-read the Tutorial section covering — Applications need **machine-readable output** — reliability ...')

# %% [markdown]
# ### Q2. True or False — can you explain this in your own words?
#
# > Use the provider's **structured-output/JSON mode**; prompt-only JSON eventually breaks.

# %%
print('Self-check: re-read the Tutorial section covering — Use the provider's **structured-output/JSON mode**; prompt-o...')

# %% [markdown]
# ### Q3. True or False — can you explain this in your own words?
#
# > **Always validate** LLM output in code — treat it as untrusted.

# %%
print('Self-check: re-read the Tutorial section covering — **Always validate** LLM output in code — treat it as untrust...')

# %% [markdown]
# ### Q4. True or False — can you explain this in your own words?
#
# > **Pydantic + Literal types** force valid categories and shapes.

# %%
print('Self-check: re-read the Tutorial section covering — **Pydantic + Literal types** force valid categories and shap...')

# %% [markdown]
# ### Q5. True or False — can you explain this in your own words?
#
# > **Tool calling** lets the model request actions; *your code* executes them.

# %%
print('Self-check: re-read the Tutorial section covering — **Tool calling** lets the model request actions; *your code*...')

# %% [markdown]
# ### Q6. True or False — can you explain this in your own words?
#
# > Tool **descriptions are prompts** — write them carefully.

# %%
print('Self-check: re-read the Tutorial section covering — Tool **descriptions are prompts** — write them carefully....')
