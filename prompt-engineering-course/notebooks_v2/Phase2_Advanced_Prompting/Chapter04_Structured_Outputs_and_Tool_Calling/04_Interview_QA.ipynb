# %% [markdown]
# # Module 4 — Interview Q&A: Structured Outputs & Tool Calling
# ### Prompt Engineering Mastery — PJ's Academy

# %% [markdown]
# > **Optional Reading**
# > Interview questions for self-study — not required before the next module.
# > Return here when preparing for interviews.

# %% [markdown]
# ## 🟢 Junior
# ### Q1: What is — Applications need **machine-readable output** — reliability is the whole game.
#
# **Answer:**
# Applications need **machine-readable output** — reliability is the whole game. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q2: How does — Use the provider's **structured-output/JSON mode**; prompt-only JSON eventually breaks.
#
# **Answer:**
# Use the provider's **structured-output/JSON mode**; prompt-only JSON eventually breaks. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q3: When/why would you — **Always validate** LLM output in code — treat it as untrusted.
#
# **Answer:**
# **Always validate** LLM output in code — treat it as untrusted. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟢 Junior
# ### Q4: What is — **Pydantic + Literal types** force valid categories and shapes.
#
# **Answer:**
# **Pydantic + Literal types** force valid categories and shapes. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q5: How does — **Tool calling** lets the model request actions; *your code* executes them.
#
# **Answer:**
# **Tool calling** lets the model request actions; *your code* executes them. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q6: When/why would you — Tool **descriptions are prompts** — write them carefully.
#
# **Answer:**
# Tool **descriptions are prompts** — write them carefully. (see the Tutorial for the full explanation and code example).
