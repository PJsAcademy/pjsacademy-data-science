# %% [markdown]
# # Module 4 — Exercises: Structured Outputs & Tool Calling
# ### Prompt Engineering Mastery — PJ's Academy
#
# Try each before checking the Tutorial.
#
# ---

# %% [markdown]
# ## Exercise 1
# Prompt an LLM to extract 3 fields as JSON, then parse it in Python. Break it, then fix with stricter instructions.

# %%
# your answer here

# %% [markdown]
# ## Exercise 2
# Define a Pydantic model with `Literal` categories and use it for structured extraction.

# %%
# your answer here

# %% [markdown]
# ## Exercise 3
# Design (on paper) 3 tools for a food-delivery assistant with precise descriptions and parameters.

# %%
# your answer here
