# %% [markdown]
# # Module 3 — Exercises: Advanced Reasoning Techniques
# ### Prompt Engineering Mastery — PJ's Academy
#
# Try each before checking the Tutorial.
#
# ---

# %% [markdown]
# ## Exercise 1
# Give an LLM a word problem with and without "think step by step." Compare.

# %%
# your answer here

# %% [markdown]
# ## Exercise 2
# Run a tricky logic puzzle 5 times at temperature 0.8 and take the majority answer.

# %%
# your answer here

# %% [markdown]
# ## Exercise 3
# Turn a complex request into a 3-step decomposed prompt. Note the quality jump.

# %%
# your answer here

# %% [markdown]
# ## Exercise 4
# Make the model draft → critique → refine an email. Compare draft vs final.

# %%
# your answer here
