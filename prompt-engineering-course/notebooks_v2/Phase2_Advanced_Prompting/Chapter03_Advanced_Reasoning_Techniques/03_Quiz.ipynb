# %% [markdown]
# # Module 3 Quiz — Advanced Reasoning Techniques
# ### Prompt Engineering Mastery — PJ's Academy
#
# Read each key concept, then confirm you can restate it. Reveal cells check yourself.
#
# ---

# %% [markdown]
# ### Q1. True or False — can you explain this in your own words?
#
# > **Chain-of-thought** ("think step by step") boosts multi-step accuracy by making reasoning explicit.

# %%
print('Self-check: re-read the Tutorial section covering — **Chain-of-thought** ("think step by step") boosts multi-ste...')

# %% [markdown]
# ### Q2. True or False — can you explain this in your own words?
#
# > **Self-consistency** = run CoT several times, take the majority answer.

# %%
print('Self-check: re-read the Tutorial section covering — **Self-consistency** = run CoT several times, take the major...')

# %% [markdown]
# ### Q3. True or False — can you explain this in your own words?
#
# > **Decompose** hard tasks — one prompt, one job.

# %%
print('Self-check: re-read the Tutorial section covering — **Decompose** hard tasks — one prompt, one job....')

# %% [markdown]
# ### Q4. True or False — can you explain this in your own words?
#
# > **ReAct** interleaves reasoning with tool calls — the foundation of agents.

# %%
print('Self-check: re-read the Tutorial section covering — **ReAct** interleaves reasoning with tool calls — the founda...')

# %% [markdown]
# ### Q5. True or False — can you explain this in your own words?
#
# > **Self-critique** catches errors before the user sees them.

# %%
print('Self-check: re-read the Tutorial section covering — **Self-critique** catches errors before the user sees them....')

# %% [markdown]
# ### Q6. True or False — can you explain this in your own words?
#
# > Don't over-apply — simple tasks don't need reasoning scaffolds.

# %%
print('Self-check: re-read the Tutorial section covering — Don't over-apply — simple tasks don't need reasoning scaffol...')
