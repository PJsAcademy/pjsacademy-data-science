# %% [markdown]
# # Module 3 — Interview Q&A: Advanced Reasoning Techniques
# ### Prompt Engineering Mastery — PJ's Academy

# %% [markdown]
# > **Optional Reading**
# > Interview questions for self-study — not required before the next module.
# > Return here when preparing for interviews.

# %% [markdown]
# ## 🟢 Junior
# ### Q1: What is — **Chain-of-thought** ("think step by step") boosts multi-step accuracy by making reasoning explicit.
#
# **Answer:**
# **Chain-of-thought** ("think step by step") boosts multi-step accuracy by making reasoning explicit. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q2: How does — **Self-consistency** = run CoT several times, take the majority answer.
#
# **Answer:**
# **Self-consistency** = run CoT several times, take the majority answer. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q3: When/why would you — **Decompose** hard tasks — one prompt, one job.
#
# **Answer:**
# **Decompose** hard tasks — one prompt, one job. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟢 Junior
# ### Q4: What is — **ReAct** interleaves reasoning with tool calls — the foundation of agents.
#
# **Answer:**
# **ReAct** interleaves reasoning with tool calls — the foundation of agents. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q5: How does — **Self-critique** catches errors before the user sees them.
#
# **Answer:**
# **Self-critique** catches errors before the user sees them. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q6: When/why would you — Don't over-apply — simple tasks don't need reasoning scaffolds.
#
# **Answer:**
# Don't over-apply — simple tasks don't need reasoning scaffolds. (see the Tutorial for the full explanation and code example).
