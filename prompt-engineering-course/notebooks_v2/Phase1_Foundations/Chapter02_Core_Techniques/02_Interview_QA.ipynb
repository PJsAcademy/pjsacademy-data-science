# %% [markdown]
# # Module 2 — Interview Q&A: Core Techniques: The Anatomy of a Great Prompt
# ### Prompt Engineering Mastery — PJ's Academy

# %% [markdown]
# > **Optional Reading**
# > Interview questions for self-study — not required before the next module.
# > Return here when preparing for interviews.

# %% [markdown]
# ## 🟢 Junior
# ### Q1: What is — Structure prompts with Role · Task · Context · Input · Constraints · Format.
#
# **Answer:**
# Structure prompts with Role · Task · Context · Input · Constraints · Format. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q2: How does — **Few-shot** examples are the most reliable lever — 2–5 diverse, identically-formatted.
#
# **Answer:**
# **Few-shot** examples are the most reliable lever — 2–5 diverse, identically-formatted. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q3: When/why would you — **Delimiters** separate instructions from data (and block injection).
#
# **Answer:**
# **Delimiters** separate instructions from data (and block injection). (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟢 Junior
# ### Q4: What is — Be **specific and positive**; always give the model an "I don't know" out.
#
# **Answer:**
# Be **specific and positive**; always give the model an "I don't know" out. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q5: How does — Prompt engineering is **iterative** — test on varied inputs, fix failures one at a time.
#
# **Answer:**
# Prompt engineering is **iterative** — test on varied inputs, fix failures one at a time. (see the Tutorial for the full explanation and code example).
