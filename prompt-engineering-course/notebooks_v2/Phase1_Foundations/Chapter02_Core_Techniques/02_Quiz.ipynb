# %% [markdown]
# # Module 2 Quiz — Core Techniques: The Anatomy of a Great Prompt
# ### Prompt Engineering Mastery — PJ's Academy
#
# Read each key concept, then confirm you can restate it. Reveal cells check yourself.
#
# ---

# %% [markdown]
# ### Q1. True or False — can you explain this in your own words?
#
# > Structure prompts with Role · Task · Context · Input · Constraints · Format.

# %%
print('Self-check: re-read the Tutorial section covering — Structure prompts with Role · Task · Context · Input · Const...')

# %% [markdown]
# ### Q2. True or False — can you explain this in your own words?
#
# > **Few-shot** examples are the most reliable lever — 2–5 diverse, identically-formatted.

# %%
print('Self-check: re-read the Tutorial section covering — **Few-shot** examples are the most reliable lever — 2–5 dive...')

# %% [markdown]
# ### Q3. True or False — can you explain this in your own words?
#
# > **Delimiters** separate instructions from data (and block injection).

# %%
print('Self-check: re-read the Tutorial section covering — **Delimiters** separate instructions from data (and block in...')

# %% [markdown]
# ### Q4. True or False — can you explain this in your own words?
#
# > Be **specific and positive**; always give the model an "I don't know" out.

# %%
print('Self-check: re-read the Tutorial section covering — Be **specific and positive**; always give the model an "I do...')

# %% [markdown]
# ### Q5. True or False — can you explain this in your own words?
#
# > Prompt engineering is **iterative** — test on varied inputs, fix failures one at a time.

# %%
print('Self-check: re-read the Tutorial section covering — Prompt engineering is **iterative** — test on varied inputs,...')
