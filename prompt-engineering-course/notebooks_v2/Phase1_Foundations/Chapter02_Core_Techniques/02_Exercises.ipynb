# %% [markdown]
# # Module 2 — Exercises: Core Techniques: The Anatomy of a Great Prompt
# ### Prompt Engineering Mastery — PJ's Academy
#
# Try each before checking the Tutorial.
#
# ---

# %% [markdown]
# ## Exercise 1
# Take a vague prompt and rewrite it using all 6 components. Compare outputs.

# %%
# your answer here

# %% [markdown]
# ## Exercise 2
# Build a 4-example few-shot classifier for a custom set of categories you care about.

# %%
# your answer here

# %% [markdown]
# ## Exercise 3
# Add "If not present, reply 'N/A'" to an extraction prompt and confirm it stops making things up.

# %%
# your answer here
