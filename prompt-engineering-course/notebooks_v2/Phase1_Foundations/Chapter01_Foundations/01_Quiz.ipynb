# %% [markdown]
# # Module 1 Quiz — Foundations: How LLMs Actually Work
# ### Prompt Engineering Mastery — PJ's Academy
#
# Read each key concept, then confirm you can restate it. Reveal cells check yourself.
#
# ---

# %% [markdown]
# ### Q1. True or False — can you explain this in your own words?
#
# > An LLM predicts the next token — shape the input so the right answer is the most plausible continuation.

# %%
print('Self-check: re-read the Tutorial section covering — An LLM predicts the next token — shape the input so the righ...')

# %% [markdown]
# ### Q2. True or False — can you explain this in your own words?
#
# > Everything is measured in **tokens** (cost, context, character-level weakness).

# %%
print('Self-check: re-read the Tutorial section covering — Everything is measured in **tokens** (cost, context, charact...')

# %% [markdown]
# ### Q3. True or False — can you explain this in your own words?
#
# > Each API call is **stateless**; "memory" is re-sent history.

# %%
print('Self-check: re-read the Tutorial section covering — Each API call is **stateless**; "memory" is re-sent history....')

# %% [markdown]
# ### Q4. True or False — can you explain this in your own words?
#
# > **Temperature low** for facts/code, **high** for creativity.

# %%
print('Self-check: re-read the Tutorial section covering — **Temperature low** for facts/code, **high** for creativity....')

# %% [markdown]
# ### Q5. True or False — can you explain this in your own words?
#
# > The **system prompt** is your main control surface.

# %%
print('Self-check: re-read the Tutorial section covering — The **system prompt** is your main control surface....')

# %% [markdown]
# ### Q6. True or False — can you explain this in your own words?
#
# > Hallucination comes from optimising plausibility — fix it with grounding, permission to abstain, and verification.

# %%
print('Self-check: re-read the Tutorial section covering — Hallucination comes from optimising plausibility — fix it wi...')
