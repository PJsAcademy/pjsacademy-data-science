# %% [markdown]
# # Module 1 — Exercises: Foundations: How LLMs Actually Work
# ### Prompt Engineering Mastery — PJ's Academy
#
# Try each before checking the Tutorial.
#
# ---

# %% [markdown]
# ## Exercise 1
# Take any prompt you've written and estimate its token count (use an online tokenizer). Cut it 30% without losing meaning.

# %%
# your answer here

# %% [markdown]
# ## Exercise 2
# Ask the same factual question at temperature 0 and temperature 1 (via API or playground). Note the difference in consistency.

# %%
# your answer here

# %% [markdown]
# ## Exercise 3
# Write a system prompt that turns a general chatbot into a "concise Python tutor who never gives the full answer, only hints."

# %%
# your answer here
