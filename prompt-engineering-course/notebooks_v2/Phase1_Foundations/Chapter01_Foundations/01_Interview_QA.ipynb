# %% [markdown]
# # Module 1 — Interview Q&A: Foundations: How LLMs Actually Work
# ### Prompt Engineering Mastery — PJ's Academy

# %% [markdown]
# > **Optional Reading**
# > Interview questions for self-study — not required before the next module.
# > Return here when preparing for interviews.

# %% [markdown]
# ## 🟢 Junior
# ### Q1: What is — An LLM predicts the next token — shape the input so the right answer is the most plausible continuation.
#
# **Answer:**
# An LLM predicts the next token — shape the input so the right answer is the most plausible continuation. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q2: How does — Everything is measured in **tokens** (cost, context, character-level weakness).
#
# **Answer:**
# Everything is measured in **tokens** (cost, context, character-level weakness). (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q3: When/why would you — Each API call is **stateless**; "memory" is re-sent history.
#
# **Answer:**
# Each API call is **stateless**; "memory" is re-sent history. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟢 Junior
# ### Q4: What is — **Temperature low** for facts/code, **high** for creativity.
#
# **Answer:**
# **Temperature low** for facts/code, **high** for creativity. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🟡 Mid
# ### Q5: How does — The **system prompt** is your main control surface.
#
# **Answer:**
# The **system prompt** is your main control surface. (see the Tutorial for the full explanation and code example).

# %% [markdown]
# ## 🔴 Senior
# ### Q6: When/why would you — Hallucination comes from optimising plausibility — fix it with grounding, permission to abstain, and verification.
#
# **Answer:**
# Hallucination comes from optimising plausibility — fix it with grounding, permission to abstain, and verification. (see the Tutorial for the full explanation and code example).
